# %%
# Necessary Libraries
import numpy as np
import pandas as pd

# for making features
from scipy import stats
from scipy.signal import find_peaks

# %% [markdown]
# ## Participant-1

# %%
# load data for participant-1
p1 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_1.csv",header=1)

# %%
p1.head(4)
# Out:
#      time_stamp       Ax      Ay       Az       Lx      Ly       Lz       Gx  \
# 0  1.390000e+12 -1.81150 -14.873 -1.34840 -1.26910 -5.1057 -0.66445 -0.53206
# 1  1.390000e+12  0.24517 -14.070 -0.84446  0.70147 -4.2969 -0.17199 -0.25229
# 2  1.390000e+12 -0.57205 -14.628 -1.75700 -0.21760 -4.8531 -1.05650 -1.04920
# 3  1.390000e+12 -0.69464 -12.939 -3.09180 -0.32273 -3.1786 -2.21970 -2.37200
#
#         Gy       Gz  ...    Lx.4     Ly.4      Lz.4     Gx.4     Gy.4  \
# 0 -3.18690  0.23976  ... -5.3574 -0.95749  0.318860  0.52565 -0.18815
# 1 -1.79660  0.40745  ... -4.5352 -0.67629  0.081656  0.43616  0.16371
# 2  0.29138  0.29230  ... -4.0408 -0.55974 -0.523690  0.32284  0.43127
# 3  1.00820  0.34972  ... -3.5908  0.15795 -1.880200  0.20403  0.72846
#
#       Gz.4   Mx.4  My.4  Mz.4  Unnamed: 69
# 0  0.28588 -22.20  6.48  4.56      walking
# 1  0.19823 -21.90  7.14  5.34      walking
# 2  0.21197 -21.60  7.50  5.64      walking
# 3  0.16493 -21.12  8.40  6.12      walking
#
# ...

# %%
pd.set_option('display.max_columns',70)
p1
# Out:
#          time_stamp        Ax       Ay        Az       Lx      Ly        Lz  \
# 0      1.390000e+12 -1.811500 -14.8730 -1.348400 -1.26910 -5.1057 -0.664450
# 1      1.390000e+12  0.245170 -14.0700 -0.844460  0.70147 -4.2969 -0.171990
# 2      1.390000e+12 -0.572050 -14.6280 -1.757000 -0.21760 -4.8531 -1.056500
# 3      1.390000e+12 -0.694640 -12.9390 -3.091800 -0.32273 -3.1786 -2.219700
# 4      1.390000e+12  0.871700 -12.0000 -1.566300  1.13740 -2.2390 -0.654760
# ...             ...       ...      ...       ...      ...     ...       ...
# 62995  1.390000e+12  0.054481  -7.8589 -2.982900 -1.57750  1.7975 -3.492600
# 62996  1.390000e+12  0.844460  -7.5593 -2.329100 -0.79722  2.1015 -2.708100
# 62997  1.390000e+12  0.354130  -6.5786 -0.095342 -1.29470  3.0850 -0.350820
# 62998  1.390000e+12  0.122580  -6.4833  0.245170 -1.52370  3.1816  0.021841
# 62999  1.390000e+12 -0.640160  -7.1643 -1.103200 -2.45230  2.5070 -1.189900
#
# ...

# %%
pd.reset_option('display.max_columns')

# %%
#all columns of d5_p1
p1.columns
# Out:
# Index(['time_stamp', 'Ax', 'Ay', 'Az', 'Lx', 'Ly', 'Lz', 'Gx', 'Gy', 'Gz',
#        'Mx', 'My', 'Mz', 'Unnamed: 13', 'time_stamp.1', 'Ax.1', 'Ay.1', 'Az.1',
#        'Lx.1', 'Ly.1', 'Lz.1', 'Gx.1', 'Gy.1', 'Gz.1', 'Mx.1', 'My.1', 'Mz.1',
#        'Unnamed: 27', 'time_stamp.2', 'Ax.2', 'Ay.2', 'Az.2', 'Lx.2', 'Ly.2',
#        'Lz.2', 'Gx.2', 'Gy.2', 'Gz.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
#        'time_stamp.3', 'Ax.3', 'Ay.3', 'Az.3', 'Lx.3', 'Ly.3', 'Lz.3', 'Gx.3',
#        'Gy.3', 'Gz.3', 'Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4',
#        'Ax.4', 'Ay.4', 'Az.4', 'Lx.4', 'Ly.4', 'Lz.4', 'Gx.4', 'Gy.4', 'Gz.4',
#        'Mx.4', 'My.4', 'Mz.4', 'Unnamed: 69'],
#       dtype='object')

# %%
# renaming column of label
p1.rename(columns={'Unnamed: 69':'label'},inplace=True)
p1.head(1)
# Out:
#      time_stamp      Ax      Ay      Az      Lx      Ly       Lz       Gx  \
# 0  1.390000e+12 -1.8115 -14.873 -1.3484 -1.2691 -5.1057 -0.66445 -0.53206
#
#        Gy       Gz  ...    Lx.4     Ly.4     Lz.4     Gx.4     Gy.4     Gz.4  \
# 0 -3.1869  0.23976  ... -5.3574 -0.95749  0.31886  0.52565 -0.18815  0.28588
#
#    Mx.4  My.4  Mz.4    label
# 0 -22.2  6.48  4.56  walking
#
# [1 rows x 70 columns]

# %%
p1.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

# %%
p1.columns
# Out:
# Index(['Ax', 'Ay', 'Az', 'Lx', 'Ly', 'Lz', 'Gx', 'Gy', 'Gz', 'Ax.1', 'Ay.1',
#        'Az.1', 'Lx.1', 'Ly.1', 'Lz.1', 'Gx.1', 'Gy.1', 'Gz.1', 'Ax.2', 'Ay.2',
#        'Az.2', 'Lx.2', 'Ly.2', 'Lz.2', 'Gx.2', 'Gy.2', 'Gz.2', 'Ax.3', 'Ay.3',
#        'Az.3', 'Lx.3', 'Ly.3', 'Lz.3', 'Gx.3', 'Gy.3', 'Gz.3', 'Ax.4', 'Ay.4',
#        'Az.4', 'Lx.4', 'Ly.4', 'Lz.4', 'Gx.4', 'Gy.4', 'Gz.4', 'label'],
#       dtype='object')

# %%
p1.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)

# %%
pd.set_option('display.max_columns',70)
p1.head(5)
# Out:
#      Ax_LP   Ay_LP    Az_LP    Lx_LP   Ly_LP    Lz_LP    Gx_LP    Gy_LP  \
# 0 -1.81150 -14.873 -1.34840 -1.26910 -5.1057 -0.66445 -0.53206 -3.18690
# 1  0.24517 -14.070 -0.84446  0.70147 -4.2969 -0.17199 -0.25229 -1.79660
# 2 -0.57205 -14.628 -1.75700 -0.21760 -4.8531 -1.05650 -1.04920  0.29138
# 3 -0.69464 -12.939 -3.09180 -0.32273 -3.1786 -2.21970 -2.37200  1.00820
# 4  0.87170 -12.000 -1.56630  1.13740 -2.2390 -0.65476 -2.79010  0.65485
#
#      Gz_LP    Ax_RP   Ay_RP   Az_RP    Lx_RP   Ly_RP    Lz_RP   Gx_RP  \
# 0  0.23976 -1.19860 -13.852  3.7865 -1.76980 -4.0625  3.89850 -3.6255
# 1  0.40745 -2.38360 -16.590  2.9965 -2.70250 -6.7890  2.86820 -3.4899
# 2  0.29230 -4.63090 -16.603  2.0703 -4.34550 -6.8081  1.68890 -3.3851
# 3  0.34972 -4.78070 -16.453  1.1577 -4.19540 -6.6731  0.74084 -3.1017
# 4  0.22724 -0.92618 -12.190 -1.0624 -0.18116 -2.4144 -1.28500 -2.7587
#
#      Gy_RP    Gz_RP    Ax_Wr   Ay_Wr   Az_Wr   Lx_Wr   Ly_Wr     Lz_Wr  \
# ...

# %%
pd.reset_option('display.max_columns')

# %%
p1.shape
# Out:
# (63000, 46)

# %%
p1.columns
# Out:
# Index(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
#        'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
#        'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
#        'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
#        'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
#        'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],
#       dtype='object')

# %%
p1['Acc_x'] = p1[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p1['Acc_y'] = p1[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p1['Acc_z'] = p1[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p1['Lin_x'] = p1[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p1['Lin_y'] = p1[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p1['Lin_z'] = p1[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p1['Gyro_x'] = p1[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p1['Gyro_y'] = p1[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p1['Gyro_z'] = p1[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

# %%
p1.shape
# Out:
# (63000, 55)

# %%
p1.columns
# Out:
# Index(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
#        'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
#        'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
#        'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
#        'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
#        'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label',
#        'Acc_x', 'Acc_y', 'Acc_z', 'Lin_x', 'Lin_y', 'Lin_z', 'Gyro_x',
#        'Gyro_y', 'Gyro_z'],
#       dtype='object')

# %%
p1['label_of_activity']=p1['label']

# %%
p1.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

# %%
p1.columns
# Out:
# Index(['Acc_x', 'Acc_y', 'Acc_z', 'Lin_x', 'Lin_y', 'Lin_z', 'Gyro_x',
#        'Gyro_y', 'Gyro_z', 'label_of_activity'],
#       dtype='object')

# %%
p1.shape
# Out:
# (63000, 10)

# %%
p1.to_csv('p1.csv', index_label='ID')

# %% [markdown]
# # Participant-2

# %%
# load data for participant-2
p2 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_2.csv",header=1)

# renaming column of label
p2.rename(columns={'Unnamed: 69':'label'},inplace=True)

p2.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p2.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p2['Acc_x'] = p2[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p2['Acc_y'] = p2[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p2['Acc_z'] = p2[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p2['Lin_x'] = p2[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p2['Lin_y'] = p2[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p2['Lin_z'] = p2[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p2['Gyro_x'] = p2[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p2['Gyro_y'] = p2[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p2['Gyro_z'] = p2[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p2['label_of_activity']=p2['label']

p2.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)


p2.to_csv('p2.csv', index_label='ID')

# %%
# load data for participant-3
p3 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_3.csv",header=1)

# renaming column of label
p3.rename(columns={'Unnamed: 69':'label'},inplace=True)

p3.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p3.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p3['Acc_x'] = p3[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p3['Acc_y'] = p3[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p3['Acc_z'] = p3[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p3['Lin_x'] = p3[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p3['Lin_y'] = p3[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p3['Lin_z'] = p3[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p3['Gyro_x'] = p3[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p3['Gyro_y'] = p3[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p3['Gyro_z'] = p3[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p3['label_of_activity']=p3['label']

p3.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p3.to_csv('p3.csv', index_label='ID')

# %%
# load data for participant-4
p4 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_4.csv",header=1)

# renaming column of label
p4.rename(columns={'Unnamed: 69':'label'},inplace=True)

p4.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p4.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p4['Acc_x'] = p4[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p4['Acc_y'] = p4[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p4['Acc_z'] = p4[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p4['Lin_x'] = p4[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p4['Lin_y'] = p4[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p4['Lin_z'] = p4[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p4['Gyro_x'] = p4[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p4['Gyro_y'] = p4[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p4['Gyro_z'] = p4[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p4['label_of_activity']=p4['label']

p4.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p4.to_csv('p4.csv', index_label='ID')

# %%
# load data for participant-5
p5 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_5.csv",header=1)

# renaming column of label
p5.rename(columns={'Unnamed: 69':'label'},inplace=True)

p5.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p5.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p5['Acc_x'] = p5[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p5['Acc_y'] = p5[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p5['Acc_z'] = p5[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p5['Lin_x'] = p5[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p5['Lin_y'] = p5[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p5['Lin_z'] = p5[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p5['Gyro_x'] = p5[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p5['Gyro_y'] = p5[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p5['Gyro_z'] = p5[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p5['label_of_activity']=p5['label']

p5.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p5.to_csv('p5.csv', index_label='ID')

# %%
# load data for participant-6
p6 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_6.csv",header=1)

# renaming column of label
p6.rename(columns={'Unnamed: 69':'label'},inplace=True)

p6.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p6.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p6['Acc_x'] = p6[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p6['Acc_y'] = p6[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p6['Acc_z'] = p6[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p6['Lin_x'] = p6[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p6['Lin_y'] = p6[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p6['Lin_z'] = p6[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p6['Gyro_x'] = p6[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p6['Gyro_y'] = p6[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p6['Gyro_z'] = p6[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p6['label_of_activity']=p6['label']

p6.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p6.to_csv('p6.csv', index_label='ID')

# %%
# load data for participant-7
p7 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_7.csv",header=1)

# renaming column of label
p7.rename(columns={'Unnamed: 69':'label'},inplace=True)

p7.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p7.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p7['Acc_x'] = p7[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p7['Acc_y'] = p7[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p7['Acc_z'] = p7[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p7['Lin_x'] = p7[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p7['Lin_y'] = p7[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p7['Lin_z'] = p7[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p7['Gyro_x'] = p7[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p7['Gyro_y'] = p7[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p7['Gyro_z'] = p7[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p7['label_of_activity']=p7['label']

p7.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p7.to_csv('p7.csv', index_label='ID')

# %%
# load data for participant-8
p8 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_8.csv",header=1)
p8.replace('upsatirs','upstairs',inplace=True)
# renaming column of label
p8.rename(columns={'Unnamed: 69':'label'},inplace=True)

p8.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p8.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p8['Acc_x'] = p8[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p8['Acc_y'] = p8[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p8['Acc_z'] = p8[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p8['Lin_x'] = p8[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p8['Lin_y'] = p8[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p8['Lin_z'] = p8[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p8['Gyro_x'] = p8[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p8['Gyro_y'] = p8[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p8['Gyro_z'] = p8[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p8['label_of_activity']=p8['label']

p8.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p8.to_csv('p8.csv', index_label='ID')

# %%
# load data for participant-9
p9 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_9.csv",header=1)

# renaming column of label
p9.rename(columns={'Unnamed: 69':'label'},inplace=True)

p9.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p9.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p9['Acc_x'] = p9[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p9['Acc_y'] = p9[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p9['Acc_z'] = p9[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p9['Lin_x'] = p9[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p9['Lin_y'] = p9[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p9['Lin_z'] = p9[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p9['Gyro_x'] = p9[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p9['Gyro_y'] = p9[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p9['Gyro_z'] = p9[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p9['label_of_activity']=p9['label']

p9.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p9.to_csv('p9.csv', index_label='ID')

# %%
# load data for participant-10
p10 = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_10.csv",header=1)

# renaming column of label
p10.rename(columns={'Unnamed: 69':'label'},inplace=True)

p10.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)

p10.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)


p10['Acc_x'] = p10[['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']].mean(axis=1)
p10['Acc_y'] = p10[['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']].mean(axis=1)
p10['Acc_z'] = p10[['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']].mean(axis=1)

p10['Lin_x'] = p10[['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']].mean(axis=1)
p10['Lin_y'] = p10[['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']].mean(axis=1)
p10['Lin_z'] = p10[['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']].mean(axis=1)

p10['Gyro_x'] = p10[['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']].mean(axis=1)
p10['Gyro_y'] = p10[['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']].mean(axis=1)
p10['Gyro_z'] = p10[['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']].mean(axis=1)

p10['label_of_activity']=p10['label']

p10.drop(['Ax_LP', 'Ay_LP', 'Az_LP', 'Lx_LP', 'Ly_LP', 'Lz_LP', 'Gx_LP', 'Gy_LP',
       'Gz_LP', 'Ax_RP', 'Ay_RP', 'Az_RP', 'Lx_RP', 'Ly_RP', 'Lz_RP', 'Gx_RP',
       'Gy_RP', 'Gz_RP', 'Ax_Wr', 'Ay_Wr', 'Az_Wr', 'Lx_Wr', 'Ly_Wr', 'Lz_Wr',
       'Gx_Wr', 'Gy_Wr', 'Gz_Wr', 'Ax_UA', 'Ay_UA', 'Az_UA', 'Lx_UA', 'Ly_UA',
       'Lz_UA', 'Gx_UA', 'Gy_UA', 'Gz_UA', 'Ax_Blt', 'Ay_Blt', 'Az_Blt',
       'Lx_Blt', 'Ly_Blt', 'Lz_Blt', 'Gx_Blt', 'Gy_Blt', 'Gz_Blt', 'label'],axis=1,inplace=True)

p10.to_csv('p10.csv', index_label='ID')

# %% [markdown]
# # Features from p1

# %%
# merging X and y from validation data to
#p1 = d5_X_validation
#p1['label'] = d5_y_validation


# creating 20% overlaping windows of size window-size 150 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p1_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p1.shape[0] - window_size, step_size):
    xs_Acc = p1['Acc_x'].values[i: i + 150]
    ys_Acc = p1['Acc_y'].values[i: i + 150]
    zs_Acc = p1['Acc_z'].values[i: i + 150]
    xs_Lin = p1['Lin_x'].values[i: i + 150]
    ys_Lin = p1['Lin_y'].values[i: i + 150]
    zs_Lin = p1['Lin_z'].values[i: i + 150]
    xs_Gyro = p1['Gyro_x'].values[i: i + 150]
    ys_Gyro = p1['Gyro_y'].values[i: i + 150]
    zs_Gyro = p1['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p1['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p1_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p1_features = pd.DataFrame()


# mean
p1_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p1_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p1_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p1_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p1_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p1_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p1_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p1_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p1_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p1_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p1_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p1_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p1_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p1_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p1_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p1_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p1_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p1_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p1_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p1_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p1_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p1_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p1_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p1_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p1_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p1_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p1_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p1_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p1_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p1_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p1_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p1_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p1_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p1_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p1_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p1_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p1_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p1_features['x_maxmin_diff_Acc'] =  p1_features['x_max_Acc'] - p1_features['x_min_Acc']
p1_features['y_maxmin_diff_Acc'] =  p1_features['y_max_Acc'] - p1_features['y_min_Acc']
p1_features['z_maxmin_diff_Acc'] =  p1_features['z_max_Acc'] - p1_features['z_min_Acc']
p1_features['x_maxmin_diff_Lin'] =  p1_features['x_max_Lin'] - p1_features['x_min_Lin']
p1_features['y_maxmin_diff_Lin'] =  p1_features['y_max_Lin'] - p1_features['y_min_Lin']
p1_features['z_maxmin_diff_Lin'] =  p1_features['z_max_Lin'] - p1_features['z_min_Lin']
p1_features['x_maxmin_diff_Gyro'] =  p1_features['x_max_Gyro'] - p1_features['x_min_Gyro']
p1_features['y_maxmin_diff_Gyro'] =  p1_features['y_max_Gyro'] - p1_features['y_min_Gyro']
p1_features['z_maxmin_diff_Gyro'] =  p1_features['z_max_Gyro'] - p1_features['z_min_Gyro']


# median
p1_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p1_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p1_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p1_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p1_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p1_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p1_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p1_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p1_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p1_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p1_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p1_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p1_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p1_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p1_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p1_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p1_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p1_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p1_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p1_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p1_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p1_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p1_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p1_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p1_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p1_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p1_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p1_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p1_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p1_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p1_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p1_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p1_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p1_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p1_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p1_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p1_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p1_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p1_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p1_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p1_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p1_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p1_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p1_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p1_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p1_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p1_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p1_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p1_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p1_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p1_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p1_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p1_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p1_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p1_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p1_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p1_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p1_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p1_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p1_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p1_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p1_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p1_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p1_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p1_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p1_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p1_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p1_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p1_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p1_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p1_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p1_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p1_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p1_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p1_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p1_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p1_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p1_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p1_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p1_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p1_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p1_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p1_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p1_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p1_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p1_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p1_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p1_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p1_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p1_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p1_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p1_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p1_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p1_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p1_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p1_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p1_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p1_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p1_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p1_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p1_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p1_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p1_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p1_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p1_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p1_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p1_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p1_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p1_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p1_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p1_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p1_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p1_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p1_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p1_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p1_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p1_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p1_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p1_features['x_maxmin_diff_fft_Acc'] =     p1_features['x_max_fft_Acc'] - p1_features['x_min_fft_Acc']
p1_features['y_maxmin_diff_fft_Acc'] =     p1_features['y_max_fft_Acc'] - p1_features['y_min_fft_Acc']
p1_features['z_maxmin_diff_fft_Acc'] =     p1_features['z_max_fft_Acc'] - p1_features['z_min_fft_Acc']
p1_features['x_maxmin_diff_fft_Lin'] =     p1_features['x_max_fft_Lin'] - p1_features['x_min_fft_Lin']
p1_features['y_maxmin_diff_fft_Lin'] =     p1_features['y_max_fft_Lin'] - p1_features['y_min_fft_Lin']
p1_features['z_maxmin_diff_fft_Lin'] =     p1_features['z_max_fft_Lin'] - p1_features['z_min_fft_Lin']
p1_features['x_maxmin_diff_fft_Gyro'] =     p1_features['x_max_fft_Gyro'] - p1_features['x_min_fft_Gyro']
p1_features['y_maxmin_diff_fft_Gyro'] =     p1_features['y_max_fft_Gyro'] - p1_features['y_min_fft_Gyro']
p1_features['z_maxmin_diff_fft_Gyro'] =     p1_features['z_max_fft_Gyro'] - p1_features['z_min_fft_Gyro']

# FFT median
p1_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p1_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p1_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p1_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p1_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p1_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p1_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p1_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p1_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p1_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p1_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p1_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p1_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p1_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p1_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p1_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p1_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p1_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p1_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p1_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p1_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p1_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p1_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p1_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p1_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p1_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p1_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p1_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p1_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p1_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p1_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p1_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p1_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p1_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p1_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p1_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p1_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p1_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p1_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p1_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p1_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p1_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p1_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p1_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p1_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p1_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p1_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p1_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p1_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p1_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p1_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p1_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p1_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p1_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p1_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p1_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p1_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p1_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p1_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p1_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p1_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p1_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p1_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p1_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p1_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p1_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p1_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p1_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p1_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p1_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p1_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p1_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p1_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p1_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p1_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p1_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p1_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p1_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p1_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p1_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p1_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p1_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p1_features['x_arg_diff_Acc'] = abs(    p1_features['x_argmax_Acc'] -     p1_features['x_argmin_Acc'])
p1_features['y_arg_diff_Acc'] = abs(    p1_features['y_argmax_Acc'] -     p1_features['y_argmin_Acc'])
p1_features['z_arg_diff_Acc'] = abs(    p1_features['z_argmax_Acc'] -     p1_features['z_argmin_Acc'])
p1_features['x_arg_diff_Lin'] = abs(    p1_features['x_argmax_Lin'] -     p1_features['x_argmin_Lin'])
p1_features['y_arg_diff_Lin'] = abs(    p1_features['y_argmax_Lin'] -     p1_features['y_argmin_Lin'])
p1_features['z_arg_diff_Lin'] = abs(    p1_features['z_argmax_Lin'] -     p1_features['z_argmin_Lin'])
p1_features['x_arg_diff_Gyro'] = abs(    p1_features['x_argmax_Gyro'] -     p1_features['x_argmin_Gyro'])
p1_features['y_arg_diff_Gyro'] = abs(    p1_features['y_argmax_Gyro'] -     p1_features['y_argmin_Gyro'])
p1_features['z_arg_diff_Gyro'] = abs(    p1_features['z_argmax_Gyro'] -     p1_features['z_argmin_Gyro'])


# index of max value in frequency domain
p1_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p1_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p1_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p1_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p1_features['x_arg_diff_fft_Acc'] = abs(p1_features['x_argmax_fft_Acc'] - p1_features['x_argmin_fft_Acc'])
p1_features['y_arg_diff_fft_Acc'] = abs(p1_features['y_argmax_fft_Acc'] - p1_features['y_argmin_fft_Acc'])
p1_features['z_arg_diff_fft_Acc'] = abs(p1_features['z_argmax_fft_Acc'] - p1_features['z_argmin_fft_Acc'])
p1_features['x_arg_diff_fft_Lin'] = abs(p1_features['x_argmax_fft_Lin'] - p1_features['x_argmin_fft_Lin'])
p1_features['y_arg_diff_fft_Lin'] = abs(p1_features['y_argmax_fft_Lin'] - p1_features['y_argmin_fft_Lin'])
p1_features['z_arg_diff_fft_Lin'] = abs(p1_features['z_argmax_fft_Lin'] - p1_features['z_argmin_fft_Lin'])
p1_features['x_arg_diff_fft_Gyro'] = abs(p1_features['x_argmax_fft_Gyro'] - p1_features['x_argmin_fft_Gyro'])
p1_features['y_arg_diff_fft_Gyro'] = abs(p1_features['y_argmax_fft_Gyro'] - p1_features['y_argmin_fft_Gyro'])
p1_features['z_arg_diff_fft_Gyro'] = abs(p1_features['z_argmax_fft_Gyro'] - p1_features['z_argmin_fft_Gyro'])

p1_features['label_of_activity']=p1_labels

# %%
p1_features
# Out:
#       x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0       3.030197   -8.305953    0.092324    0.117246   -0.571045    0.177267
# 1       3.021265   -8.341569    0.168419   -0.091852   -0.639241    0.194135
# 2       3.113552   -8.211453    0.150912    0.193602   -0.474490    0.192857
# 3       2.935254   -8.307903    0.041207   -0.094728   -0.613727    0.056220
# 4       2.968238   -8.303224    0.073024   -0.006570   -0.613585    0.123650
# ...          ...         ...         ...         ...         ...         ...
# 2090    2.717099   -7.804860   -1.362925    0.026310    0.022152    0.037421
# 2091    2.756015   -7.947984   -1.318359    0.018495   -0.106081    0.102791
# 2092    2.736238   -7.924537   -1.347379   -0.014716   -0.098562    0.094878
# 2093    2.838555   -7.966159   -1.413610    0.090046   -0.136661   -0.012116
# 2094    2.845926   -7.958751   -1.390982    0.076801   -0.142387    0.013301
#
# ...

# %%
# storing the obtained dataframe to csv
p1_features.to_csv('p1_features.csv',index_label='ID')

# %% [markdown]
# # Features from p2

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p2_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p2.shape[0] - window_size, step_size):
    xs_Acc = p2['Acc_x'].values[i: i + 150]
    ys_Acc = p2['Acc_y'].values[i: i + 150]
    zs_Acc = p2['Acc_z'].values[i: i + 150]
    xs_Lin = p2['Lin_x'].values[i: i + 150]
    ys_Lin = p2['Lin_y'].values[i: i + 150]
    zs_Lin = p2['Lin_z'].values[i: i + 150]
    xs_Gyro = p2['Gyro_x'].values[i: i + 150]
    ys_Gyro = p2['Gyro_y'].values[i: i + 150]
    zs_Gyro = p2['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p2['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p2_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p2_features = pd.DataFrame()


# mean
p2_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p2_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p2_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p2_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p2_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p2_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p2_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p2_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p2_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p2_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p2_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p2_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p2_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p2_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p2_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p2_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p2_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p2_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p2_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p2_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p2_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p2_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p2_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p2_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p2_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p2_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p2_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p2_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p2_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p2_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p2_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p2_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p2_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p2_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p2_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p2_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p2_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p2_features['x_maxmin_diff_Acc'] =  p2_features['x_max_Acc'] - p2_features['x_min_Acc']
p2_features['y_maxmin_diff_Acc'] =  p2_features['y_max_Acc'] - p2_features['y_min_Acc']
p2_features['z_maxmin_diff_Acc'] =  p2_features['z_max_Acc'] - p2_features['z_min_Acc']
p2_features['x_maxmin_diff_Lin'] =  p2_features['x_max_Lin'] - p2_features['x_min_Lin']
p2_features['y_maxmin_diff_Lin'] =  p2_features['y_max_Lin'] - p2_features['y_min_Lin']
p2_features['z_maxmin_diff_Lin'] =  p2_features['z_max_Lin'] - p2_features['z_min_Lin']
p2_features['x_maxmin_diff_Gyro'] =  p2_features['x_max_Gyro'] - p2_features['x_min_Gyro']
p2_features['y_maxmin_diff_Gyro'] =  p2_features['y_max_Gyro'] - p2_features['y_min_Gyro']
p2_features['z_maxmin_diff_Gyro'] =  p2_features['z_max_Gyro'] - p2_features['z_min_Gyro']


# median
p2_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p2_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p2_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p2_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p2_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p2_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p2_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p2_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p2_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p2_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p2_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p2_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p2_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p2_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p2_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p2_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p2_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p2_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p2_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p2_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p2_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p2_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p2_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p2_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p2_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p2_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p2_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p2_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p2_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p2_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p2_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p2_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p2_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p2_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p2_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p2_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p2_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p2_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p2_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p2_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p2_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p2_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p2_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p2_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p2_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p2_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p2_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p2_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p2_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p2_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p2_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p2_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p2_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p2_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p2_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p2_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p2_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p2_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p2_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p2_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p2_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p2_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p2_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p2_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p2_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p2_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p2_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p2_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p2_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p2_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p2_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p2_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p2_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p2_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p2_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p2_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p2_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p2_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p2_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p2_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p2_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p2_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p2_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p2_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p2_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p2_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p2_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p2_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p2_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p2_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p2_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p2_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p2_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p2_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p2_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p2_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p2_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p2_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p2_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p2_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p2_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p2_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p2_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p2_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p2_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p2_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p2_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p2_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p2_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p2_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p2_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p2_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p2_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p2_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p2_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p2_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p2_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p2_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p2_features['x_maxmin_diff_fft_Acc'] =     p2_features['x_max_fft_Acc'] - p2_features['x_min_fft_Acc']
p2_features['y_maxmin_diff_fft_Acc'] =     p2_features['y_max_fft_Acc'] - p2_features['y_min_fft_Acc']
p2_features['z_maxmin_diff_fft_Acc'] =     p2_features['z_max_fft_Acc'] - p2_features['z_min_fft_Acc']
p2_features['x_maxmin_diff_fft_Lin'] =     p2_features['x_max_fft_Lin'] - p2_features['x_min_fft_Lin']
p2_features['y_maxmin_diff_fft_Lin'] =     p2_features['y_max_fft_Lin'] - p2_features['y_min_fft_Lin']
p2_features['z_maxmin_diff_fft_Lin'] =     p2_features['z_max_fft_Lin'] - p2_features['z_min_fft_Lin']
p2_features['x_maxmin_diff_fft_Gyro'] =     p2_features['x_max_fft_Gyro'] - p2_features['x_min_fft_Gyro']
p2_features['y_maxmin_diff_fft_Gyro'] =     p2_features['y_max_fft_Gyro'] - p2_features['y_min_fft_Gyro']
p2_features['z_maxmin_diff_fft_Gyro'] =     p2_features['z_max_fft_Gyro'] - p2_features['z_min_fft_Gyro']

# FFT median
p2_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p2_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p2_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p2_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p2_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p2_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p2_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p2_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p2_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p2_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p2_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p2_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p2_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p2_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p2_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p2_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p2_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p2_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p2_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p2_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p2_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p2_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p2_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p2_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p2_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p2_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p2_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p2_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p2_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p2_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p2_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p2_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p2_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p2_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p2_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p2_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p2_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p2_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p2_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p2_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p2_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p2_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p2_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p2_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p2_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p2_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p2_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p2_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p2_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p2_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p2_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p2_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p2_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p2_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p2_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p2_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p2_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p2_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p2_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p2_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p2_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p2_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p2_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p2_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p2_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p2_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p2_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p2_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p2_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p2_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p2_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p2_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p2_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p2_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p2_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p2_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p2_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p2_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p2_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p2_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p2_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p2_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p2_features['x_arg_diff_Acc'] = abs(    p2_features['x_argmax_Acc'] -     p2_features['x_argmin_Acc'])
p2_features['y_arg_diff_Acc'] = abs(    p2_features['y_argmax_Acc'] -     p2_features['y_argmin_Acc'])
p2_features['z_arg_diff_Acc'] = abs(    p2_features['z_argmax_Acc'] -     p2_features['z_argmin_Acc'])
p2_features['x_arg_diff_Lin'] = abs(    p2_features['x_argmax_Lin'] -     p2_features['x_argmin_Lin'])
p2_features['y_arg_diff_Lin'] = abs(    p2_features['y_argmax_Lin'] -     p2_features['y_argmin_Lin'])
p2_features['z_arg_diff_Lin'] = abs(    p2_features['z_argmax_Lin'] -     p2_features['z_argmin_Lin'])
p2_features['x_arg_diff_Gyro'] = abs(    p2_features['x_argmax_Gyro'] -     p2_features['x_argmin_Gyro'])
p2_features['y_arg_diff_Gyro'] = abs(    p2_features['y_argmax_Gyro'] -     p2_features['y_argmin_Gyro'])
p2_features['z_arg_diff_Gyro'] = abs(    p2_features['z_argmax_Gyro'] -     p2_features['z_argmin_Gyro'])


# index of max value in frequency domain
p2_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p2_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p2_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p2_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p2_features['x_arg_diff_fft_Acc'] = abs(p2_features['x_argmax_fft_Acc'] - p2_features['x_argmin_fft_Acc'])
p2_features['y_arg_diff_fft_Acc'] = abs(p2_features['y_argmax_fft_Acc'] - p2_features['y_argmin_fft_Acc'])
p2_features['z_arg_diff_fft_Acc'] = abs(p2_features['z_argmax_fft_Acc'] - p2_features['z_argmin_fft_Acc'])
p2_features['x_arg_diff_fft_Lin'] = abs(p2_features['x_argmax_fft_Lin'] - p2_features['x_argmin_fft_Lin'])
p2_features['y_arg_diff_fft_Lin'] = abs(p2_features['y_argmax_fft_Lin'] - p2_features['y_argmin_fft_Lin'])
p2_features['z_arg_diff_fft_Lin'] = abs(p2_features['z_argmax_fft_Lin'] - p2_features['z_argmin_fft_Lin'])
p2_features['x_arg_diff_fft_Gyro'] = abs(p2_features['x_argmax_fft_Gyro'] - p2_features['x_argmin_fft_Gyro'])
p2_features['y_arg_diff_fft_Gyro'] = abs(p2_features['y_argmax_fft_Gyro'] - p2_features['y_argmin_fft_Gyro'])
p2_features['z_arg_diff_fft_Gyro'] = abs(p2_features['z_argmax_fft_Gyro'] - p2_features['z_argmin_fft_Gyro'])

p2_features['label_of_activity']=p2_labels

# %%
p2_features
# Out:
#       x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0       3.304620   -8.461805   -1.406655    0.141120   -1.033756    0.295374
# 1       3.339144   -8.462348   -1.420094    0.124134   -1.041664    0.249398
# 2       3.348574   -8.557408   -1.409616    0.171317   -1.065748    0.078740
# 3       3.388383   -8.577661   -1.319976    0.252578   -1.051342    0.139936
# 4       3.312872   -8.493834   -1.278280    0.112571   -0.961628    0.214580
# ...          ...         ...         ...         ...         ...         ...
# 2090    2.741017   -7.962528   -0.873480    0.208695   -0.279262    0.005053
# 2091    2.703317   -8.183323   -0.708783    0.140785   -0.528894    0.070368
# 2092    2.764898   -7.991169   -0.734699    0.308549   -0.426074    0.327569
# 2093    2.756179   -8.032700   -0.818836    0.255460   -0.414261    0.242619
# 2094    2.875438   -7.785286   -1.120336    0.309138   -0.217887    0.361188
#
# ...

# %%
# storing the obtained dataframe to csv
p2_features.to_csv('p2_features.csv',index_label='ID')

# %% [markdown]
# # Features from p3

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p3_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p3.shape[0] - window_size, step_size):
    xs_Acc = p3['Acc_x'].values[i: i + 150]
    ys_Acc = p3['Acc_y'].values[i: i + 150]
    zs_Acc = p3['Acc_z'].values[i: i + 150]
    xs_Lin = p3['Lin_x'].values[i: i + 150]
    ys_Lin = p3['Lin_y'].values[i: i + 150]
    zs_Lin = p3['Lin_z'].values[i: i + 150]
    xs_Gyro = p3['Gyro_x'].values[i: i + 150]
    ys_Gyro = p3['Gyro_y'].values[i: i + 150]
    zs_Gyro = p3['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p3['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p3_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p3_features = pd.DataFrame()


# mean
p3_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p3_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p3_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p3_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p3_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p3_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p3_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p3_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p3_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p3_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p3_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p3_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p3_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p3_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p3_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p3_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p3_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p3_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p3_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p3_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p3_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p3_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p3_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p3_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p3_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p3_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p3_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p3_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p3_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p3_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p3_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p3_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p3_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p3_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p3_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p3_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p3_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p3_features['x_maxmin_diff_Acc'] =  p3_features['x_max_Acc'] - p3_features['x_min_Acc']
p3_features['y_maxmin_diff_Acc'] =  p3_features['y_max_Acc'] - p3_features['y_min_Acc']
p3_features['z_maxmin_diff_Acc'] =  p3_features['z_max_Acc'] - p3_features['z_min_Acc']
p3_features['x_maxmin_diff_Lin'] =  p3_features['x_max_Lin'] - p3_features['x_min_Lin']
p3_features['y_maxmin_diff_Lin'] =  p3_features['y_max_Lin'] - p3_features['y_min_Lin']
p3_features['z_maxmin_diff_Lin'] =  p3_features['z_max_Lin'] - p3_features['z_min_Lin']
p3_features['x_maxmin_diff_Gyro'] =  p3_features['x_max_Gyro'] - p3_features['x_min_Gyro']
p3_features['y_maxmin_diff_Gyro'] =  p3_features['y_max_Gyro'] - p3_features['y_min_Gyro']
p3_features['z_maxmin_diff_Gyro'] =  p3_features['z_max_Gyro'] - p3_features['z_min_Gyro']


# median
p3_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p3_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p3_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p3_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p3_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p3_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p3_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p3_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p3_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p3_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p3_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p3_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p3_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p3_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p3_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p3_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p3_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p3_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p3_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p3_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p3_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p3_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p3_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p3_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p3_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p3_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p3_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p3_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p3_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p3_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p3_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p3_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p3_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p3_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p3_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p3_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p3_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p3_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p3_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p3_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p3_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p3_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p3_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p3_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p3_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p3_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p3_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p3_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p3_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p3_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p3_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p3_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p3_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p3_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p3_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p3_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p3_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p3_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p3_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p3_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p3_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p3_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p3_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p3_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p3_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p3_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p3_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p3_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p3_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p3_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p3_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p3_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p3_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p3_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p3_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p3_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p3_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p3_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p3_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p3_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p3_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p3_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p3_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p3_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p3_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p3_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p3_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p3_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p3_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p3_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p3_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p3_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p3_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p3_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p3_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p3_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p3_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p3_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p3_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p3_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p3_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p3_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p3_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p3_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p3_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p3_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p3_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p3_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p3_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p3_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p3_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p3_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p3_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p3_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p3_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p3_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p3_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p3_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p3_features['x_maxmin_diff_fft_Acc'] =     p3_features['x_max_fft_Acc'] - p3_features['x_min_fft_Acc']
p3_features['y_maxmin_diff_fft_Acc'] =     p3_features['y_max_fft_Acc'] - p3_features['y_min_fft_Acc']
p3_features['z_maxmin_diff_fft_Acc'] =     p3_features['z_max_fft_Acc'] - p3_features['z_min_fft_Acc']
p3_features['x_maxmin_diff_fft_Lin'] =     p3_features['x_max_fft_Lin'] - p3_features['x_min_fft_Lin']
p3_features['y_maxmin_diff_fft_Lin'] =     p3_features['y_max_fft_Lin'] - p3_features['y_min_fft_Lin']
p3_features['z_maxmin_diff_fft_Lin'] =     p3_features['z_max_fft_Lin'] - p3_features['z_min_fft_Lin']
p3_features['x_maxmin_diff_fft_Gyro'] =     p3_features['x_max_fft_Gyro'] - p3_features['x_min_fft_Gyro']
p3_features['y_maxmin_diff_fft_Gyro'] =     p3_features['y_max_fft_Gyro'] - p3_features['y_min_fft_Gyro']
p3_features['z_maxmin_diff_fft_Gyro'] =     p3_features['z_max_fft_Gyro'] - p3_features['z_min_fft_Gyro']

# FFT median
p3_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p3_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p3_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p3_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p3_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p3_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p3_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p3_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p3_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p3_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p3_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p3_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p3_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p3_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p3_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p3_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p3_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p3_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p3_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p3_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p3_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p3_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p3_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p3_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p3_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p3_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p3_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p3_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p3_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p3_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p3_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p3_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p3_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p3_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p3_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p3_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p3_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p3_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p3_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p3_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p3_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p3_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p3_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p3_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p3_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p3_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p3_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p3_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p3_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p3_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p3_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p3_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p3_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p3_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p3_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p3_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p3_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p3_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p3_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p3_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p3_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p3_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p3_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p3_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p3_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p3_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p3_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p3_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p3_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p3_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p3_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p3_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p3_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p3_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p3_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p3_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p3_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p3_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p3_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p3_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p3_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p3_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p3_features['x_arg_diff_Acc'] = abs(    p3_features['x_argmax_Acc'] -     p3_features['x_argmin_Acc'])
p3_features['y_arg_diff_Acc'] = abs(    p3_features['y_argmax_Acc'] -     p3_features['y_argmin_Acc'])
p3_features['z_arg_diff_Acc'] = abs(    p3_features['z_argmax_Acc'] -     p3_features['z_argmin_Acc'])
p3_features['x_arg_diff_Lin'] = abs(    p3_features['x_argmax_Lin'] -     p3_features['x_argmin_Lin'])
p3_features['y_arg_diff_Lin'] = abs(    p3_features['y_argmax_Lin'] -     p3_features['y_argmin_Lin'])
p3_features['z_arg_diff_Lin'] = abs(    p3_features['z_argmax_Lin'] -     p3_features['z_argmin_Lin'])
p3_features['x_arg_diff_Gyro'] = abs(    p3_features['x_argmax_Gyro'] -     p3_features['x_argmin_Gyro'])
p3_features['y_arg_diff_Gyro'] = abs(    p3_features['y_argmax_Gyro'] -     p3_features['y_argmin_Gyro'])
p3_features['z_arg_diff_Gyro'] = abs(    p3_features['z_argmax_Gyro'] -     p3_features['z_argmin_Gyro'])


# index of max value in frequency domain
p3_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p3_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p3_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p3_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p3_features['x_arg_diff_fft_Acc'] = abs(p3_features['x_argmax_fft_Acc'] - p3_features['x_argmin_fft_Acc'])
p3_features['y_arg_diff_fft_Acc'] = abs(p3_features['y_argmax_fft_Acc'] - p3_features['y_argmin_fft_Acc'])
p3_features['z_arg_diff_fft_Acc'] = abs(p3_features['z_argmax_fft_Acc'] - p3_features['z_argmin_fft_Acc'])
p3_features['x_arg_diff_fft_Lin'] = abs(p3_features['x_argmax_fft_Lin'] - p3_features['x_argmin_fft_Lin'])
p3_features['y_arg_diff_fft_Lin'] = abs(p3_features['y_argmax_fft_Lin'] - p3_features['y_argmin_fft_Lin'])
p3_features['z_arg_diff_fft_Lin'] = abs(p3_features['z_argmax_fft_Lin'] - p3_features['z_argmin_fft_Lin'])
p3_features['x_arg_diff_fft_Gyro'] = abs(p3_features['x_argmax_fft_Gyro'] - p3_features['x_argmin_fft_Gyro'])
p3_features['y_arg_diff_fft_Gyro'] = abs(p3_features['y_argmax_fft_Gyro'] - p3_features['y_argmin_fft_Gyro'])
p3_features['z_arg_diff_fft_Gyro'] = abs(p3_features['z_argmax_fft_Gyro'] - p3_features['z_argmin_fft_Gyro'])

p3_features['label_of_activity']=p3_labels

# %%
p3_features
# Out:
#       x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0       2.916607   -8.161198   -1.013280   -0.025831   -0.489608    0.409123
# 1       2.935164   -8.208905   -1.012172    0.128304   -0.485645    0.240150
# 2       2.865867   -8.152697   -0.955749   -0.051508   -0.469879    0.414271
# 3       2.905892   -8.285190   -0.907860    0.078983   -0.583318    0.346248
# 4       2.940542   -8.113696   -0.935065    0.006489   -0.470584    0.457236
# ...          ...         ...         ...         ...         ...         ...
# 2090    3.075525   -7.820186   -1.930384   -0.060219   -0.124676    0.020653
# 2091    3.094631   -7.869782   -1.888506   -0.005536   -0.136593   -0.055829
# 2092    2.947149   -7.929654   -1.732036    0.028030   -0.163357   -0.132972
# 2093    2.800594   -8.060321   -1.304557   -0.025435   -0.250997    0.001381
# 2094    2.665317   -8.021455   -1.158911    0.067502   -0.170740   -0.012165
#
# ...

# %%
# storing the obtained dataframe to csv
p3_features.to_csv('p3_features.csv',index_label='ID')

# %% [markdown]
# # Features from p4

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p4_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p4.shape[0] - window_size, step_size):
    xs_Acc = p4['Acc_x'].values[i: i + 150]
    ys_Acc = p4['Acc_y'].values[i: i + 150]
    zs_Acc = p4['Acc_z'].values[i: i + 150]
    xs_Lin = p4['Lin_x'].values[i: i + 150]
    ys_Lin = p4['Lin_y'].values[i: i + 150]
    zs_Lin = p4['Lin_z'].values[i: i + 150]
    xs_Gyro = p4['Gyro_x'].values[i: i + 150]
    ys_Gyro = p4['Gyro_y'].values[i: i + 150]
    zs_Gyro = p4['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p4['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p4_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p4_features = pd.DataFrame()


# mean
p4_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p4_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p4_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p4_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p4_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p4_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p4_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p4_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p4_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p4_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p4_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p4_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p4_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p4_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p4_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p4_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p4_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p4_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p4_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p4_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p4_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p4_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p4_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p4_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p4_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p4_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p4_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p4_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p4_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p4_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p4_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p4_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p4_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p4_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p4_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p4_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p4_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p4_features['x_maxmin_diff_Acc'] =  p4_features['x_max_Acc'] - p4_features['x_min_Acc']
p4_features['y_maxmin_diff_Acc'] =  p4_features['y_max_Acc'] - p4_features['y_min_Acc']
p4_features['z_maxmin_diff_Acc'] =  p4_features['z_max_Acc'] - p4_features['z_min_Acc']
p4_features['x_maxmin_diff_Lin'] =  p4_features['x_max_Lin'] - p4_features['x_min_Lin']
p4_features['y_maxmin_diff_Lin'] =  p4_features['y_max_Lin'] - p4_features['y_min_Lin']
p4_features['z_maxmin_diff_Lin'] =  p4_features['z_max_Lin'] - p4_features['z_min_Lin']
p4_features['x_maxmin_diff_Gyro'] =  p4_features['x_max_Gyro'] - p4_features['x_min_Gyro']
p4_features['y_maxmin_diff_Gyro'] =  p4_features['y_max_Gyro'] - p4_features['y_min_Gyro']
p4_features['z_maxmin_diff_Gyro'] =  p4_features['z_max_Gyro'] - p4_features['z_min_Gyro']


# median
p4_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p4_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p4_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p4_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p4_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p4_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p4_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p4_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p4_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p4_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p4_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p4_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p4_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p4_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p4_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p4_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p4_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p4_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p4_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p4_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p4_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p4_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p4_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p4_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p4_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p4_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p4_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p4_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p4_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p4_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p4_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p4_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p4_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p4_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p4_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p4_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p4_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p4_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p4_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p4_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p4_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p4_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p4_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p4_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p4_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p4_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p4_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p4_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p4_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p4_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p4_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p4_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p4_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p4_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p4_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p4_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p4_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p4_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p4_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p4_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p4_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p4_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p4_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p4_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p4_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p4_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p4_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p4_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p4_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p4_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p4_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p4_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p4_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p4_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p4_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p4_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p4_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p4_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p4_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p4_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p4_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p4_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p4_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p4_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p4_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p4_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p4_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p4_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p4_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p4_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p4_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p4_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p4_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p4_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p4_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p4_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p4_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p4_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p4_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p4_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p4_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p4_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p4_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p4_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p4_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p4_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p4_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p4_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p4_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p4_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p4_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p4_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p4_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p4_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p4_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p4_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p4_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p4_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p4_features['x_maxmin_diff_fft_Acc'] =     p4_features['x_max_fft_Acc'] - p4_features['x_min_fft_Acc']
p4_features['y_maxmin_diff_fft_Acc'] =     p4_features['y_max_fft_Acc'] - p4_features['y_min_fft_Acc']
p4_features['z_maxmin_diff_fft_Acc'] =     p4_features['z_max_fft_Acc'] - p4_features['z_min_fft_Acc']
p4_features['x_maxmin_diff_fft_Lin'] =     p4_features['x_max_fft_Lin'] - p4_features['x_min_fft_Lin']
p4_features['y_maxmin_diff_fft_Lin'] =     p4_features['y_max_fft_Lin'] - p4_features['y_min_fft_Lin']
p4_features['z_maxmin_diff_fft_Lin'] =     p4_features['z_max_fft_Lin'] - p4_features['z_min_fft_Lin']
p4_features['x_maxmin_diff_fft_Gyro'] =     p4_features['x_max_fft_Gyro'] - p4_features['x_min_fft_Gyro']
p4_features['y_maxmin_diff_fft_Gyro'] =     p4_features['y_max_fft_Gyro'] - p4_features['y_min_fft_Gyro']
p4_features['z_maxmin_diff_fft_Gyro'] =     p4_features['z_max_fft_Gyro'] - p4_features['z_min_fft_Gyro']

# FFT median
p4_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p4_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p4_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p4_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p4_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p4_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p4_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p4_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p4_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p4_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p4_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p4_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p4_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p4_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p4_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p4_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p4_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p4_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p4_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p4_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p4_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p4_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p4_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p4_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p4_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p4_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p4_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p4_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p4_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p4_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p4_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p4_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p4_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p4_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p4_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p4_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p4_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p4_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p4_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p4_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p4_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p4_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p4_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p4_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p4_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p4_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p4_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p4_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p4_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p4_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p4_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p4_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p4_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p4_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p4_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p4_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p4_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p4_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p4_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p4_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p4_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p4_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p4_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p4_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p4_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p4_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p4_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p4_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p4_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p4_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p4_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p4_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p4_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p4_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p4_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p4_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p4_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p4_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p4_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p4_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p4_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p4_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p4_features['x_arg_diff_Acc'] = abs(    p4_features['x_argmax_Acc'] -     p4_features['x_argmin_Acc'])
p4_features['y_arg_diff_Acc'] = abs(    p4_features['y_argmax_Acc'] -     p4_features['y_argmin_Acc'])
p4_features['z_arg_diff_Acc'] = abs(    p4_features['z_argmax_Acc'] -     p4_features['z_argmin_Acc'])
p4_features['x_arg_diff_Lin'] = abs(    p4_features['x_argmax_Lin'] -     p4_features['x_argmin_Lin'])
p4_features['y_arg_diff_Lin'] = abs(    p4_features['y_argmax_Lin'] -     p4_features['y_argmin_Lin'])
p4_features['z_arg_diff_Lin'] = abs(    p4_features['z_argmax_Lin'] -     p4_features['z_argmin_Lin'])
p4_features['x_arg_diff_Gyro'] = abs(    p4_features['x_argmax_Gyro'] -     p4_features['x_argmin_Gyro'])
p4_features['y_arg_diff_Gyro'] = abs(    p4_features['y_argmax_Gyro'] -     p4_features['y_argmin_Gyro'])
p4_features['z_arg_diff_Gyro'] = abs(    p4_features['z_argmax_Gyro'] -     p4_features['z_argmin_Gyro'])


# index of max value in frequency domain
p4_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p4_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p4_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p4_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p4_features['x_arg_diff_fft_Acc'] = abs(p4_features['x_argmax_fft_Acc'] - p4_features['x_argmin_fft_Acc'])
p4_features['y_arg_diff_fft_Acc'] = abs(p4_features['y_argmax_fft_Acc'] - p4_features['y_argmin_fft_Acc'])
p4_features['z_arg_diff_fft_Acc'] = abs(p4_features['z_argmax_fft_Acc'] - p4_features['z_argmin_fft_Acc'])
p4_features['x_arg_diff_fft_Lin'] = abs(p4_features['x_argmax_fft_Lin'] - p4_features['x_argmin_fft_Lin'])
p4_features['y_arg_diff_fft_Lin'] = abs(p4_features['y_argmax_fft_Lin'] - p4_features['y_argmin_fft_Lin'])
p4_features['z_arg_diff_fft_Lin'] = abs(p4_features['z_argmax_fft_Lin'] - p4_features['z_argmin_fft_Lin'])
p4_features['x_arg_diff_fft_Gyro'] = abs(p4_features['x_argmax_fft_Gyro'] - p4_features['x_argmin_fft_Gyro'])
p4_features['y_arg_diff_fft_Gyro'] = abs(p4_features['y_argmax_fft_Gyro'] - p4_features['y_argmin_fft_Gyro'])
p4_features['z_arg_diff_fft_Gyro'] = abs(p4_features['z_argmax_fft_Gyro'] - p4_features['z_argmin_fft_Gyro'])

p4_features['label_of_activity']=p4_labels

# %%
p4_features
# Out:
#       x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0       2.823040   -8.492207   -0.911347   -0.009322   -0.791606    0.314723
# 1       2.822355   -8.499940   -0.940295   -0.012993   -0.832273    0.313211
# 2       2.827205   -8.504986   -0.927076    0.008198   -0.841518    0.314374
# 3       2.798493   -8.490097   -0.923427   -0.015275   -0.831738    0.313562
# 4       2.810281   -8.459816   -0.914745    0.020359   -0.785661    0.302926
# ...          ...         ...         ...         ...         ...         ...
# 2090    3.184031   -7.883641   -1.279441    0.590085   -1.220603    0.333737
# 2091    3.156843   -8.058161   -1.020254    0.675088   -1.167408    0.269276
# 2092    2.954863   -7.901676   -0.840594    0.370635   -0.847742    0.332690
# 2093    2.937268   -8.018572   -0.786893    0.277218   -0.764000    0.528203
# 2094    2.935235   -7.879314   -0.921735    0.457084   -0.529012    0.538002
#
# ...

# %%
# storing the obtained dataframe to csv
p4_features.to_csv('p4_features.csv',index_label='ID')

# %% [markdown]
# # Features from p5

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p5_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p5.shape[0] - window_size, step_size):
    xs_Acc = p5['Acc_x'].values[i: i + 150]
    ys_Acc = p5['Acc_y'].values[i: i + 150]
    zs_Acc = p5['Acc_z'].values[i: i + 150]
    xs_Lin = p5['Lin_x'].values[i: i + 150]
    ys_Lin = p5['Lin_y'].values[i: i + 150]
    zs_Lin = p5['Lin_z'].values[i: i + 150]
    xs_Gyro = p5['Gyro_x'].values[i: i + 150]
    ys_Gyro = p5['Gyro_y'].values[i: i + 150]
    zs_Gyro = p5['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p5['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p5_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p5_features = pd.DataFrame()


# mean
p5_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p5_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p5_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p5_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p5_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p5_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p5_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p5_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p5_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p5_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p5_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p5_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p5_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p5_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p5_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p5_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p5_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p5_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p5_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p5_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p5_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p5_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p5_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p5_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p5_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p5_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p5_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p5_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p5_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p5_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p5_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p5_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p5_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p5_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p5_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p5_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p5_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p5_features['x_maxmin_diff_Acc'] =  p5_features['x_max_Acc'] - p5_features['x_min_Acc']
p5_features['y_maxmin_diff_Acc'] =  p5_features['y_max_Acc'] - p5_features['y_min_Acc']
p5_features['z_maxmin_diff_Acc'] =  p5_features['z_max_Acc'] - p5_features['z_min_Acc']
p5_features['x_maxmin_diff_Lin'] =  p5_features['x_max_Lin'] - p5_features['x_min_Lin']
p5_features['y_maxmin_diff_Lin'] =  p5_features['y_max_Lin'] - p5_features['y_min_Lin']
p5_features['z_maxmin_diff_Lin'] =  p5_features['z_max_Lin'] - p5_features['z_min_Lin']
p5_features['x_maxmin_diff_Gyro'] =  p5_features['x_max_Gyro'] - p5_features['x_min_Gyro']
p5_features['y_maxmin_diff_Gyro'] =  p5_features['y_max_Gyro'] - p5_features['y_min_Gyro']
p5_features['z_maxmin_diff_Gyro'] =  p5_features['z_max_Gyro'] - p5_features['z_min_Gyro']


# median
p5_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p5_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p5_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p5_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p5_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p5_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p5_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p5_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p5_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p5_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p5_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p5_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p5_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p5_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p5_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p5_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p5_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p5_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p5_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p5_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p5_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p5_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p5_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p5_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p5_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p5_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p5_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p5_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p5_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p5_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p5_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p5_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p5_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p5_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p5_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p5_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p5_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p5_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p5_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p5_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p5_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p5_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p5_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p5_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p5_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p5_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p5_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p5_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p5_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p5_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p5_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p5_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p5_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p5_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p5_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p5_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p5_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p5_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p5_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p5_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p5_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p5_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p5_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p5_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p5_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p5_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p5_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p5_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p5_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p5_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p5_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p5_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p5_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p5_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p5_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p5_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p5_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p5_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p5_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p5_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p5_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p5_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p5_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p5_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p5_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p5_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p5_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p5_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p5_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p5_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p5_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p5_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p5_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p5_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p5_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p5_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p5_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p5_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p5_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p5_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p5_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p5_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p5_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p5_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p5_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p5_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p5_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p5_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p5_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p5_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p5_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p5_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p5_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p5_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p5_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p5_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p5_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p5_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p5_features['x_maxmin_diff_fft_Acc'] =     p5_features['x_max_fft_Acc'] - p5_features['x_min_fft_Acc']
p5_features['y_maxmin_diff_fft_Acc'] =     p5_features['y_max_fft_Acc'] - p5_features['y_min_fft_Acc']
p5_features['z_maxmin_diff_fft_Acc'] =     p5_features['z_max_fft_Acc'] - p5_features['z_min_fft_Acc']
p5_features['x_maxmin_diff_fft_Lin'] =     p5_features['x_max_fft_Lin'] - p5_features['x_min_fft_Lin']
p5_features['y_maxmin_diff_fft_Lin'] =     p5_features['y_max_fft_Lin'] - p5_features['y_min_fft_Lin']
p5_features['z_maxmin_diff_fft_Lin'] =     p5_features['z_max_fft_Lin'] - p5_features['z_min_fft_Lin']
p5_features['x_maxmin_diff_fft_Gyro'] =     p5_features['x_max_fft_Gyro'] - p5_features['x_min_fft_Gyro']
p5_features['y_maxmin_diff_fft_Gyro'] =     p5_features['y_max_fft_Gyro'] - p5_features['y_min_fft_Gyro']
p5_features['z_maxmin_diff_fft_Gyro'] =     p5_features['z_max_fft_Gyro'] - p5_features['z_min_fft_Gyro']

# FFT median
p5_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p5_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p5_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p5_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p5_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p5_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p5_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p5_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p5_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p5_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p5_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p5_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p5_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p5_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p5_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p5_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p5_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p5_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p5_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p5_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p5_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p5_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p5_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p5_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p5_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p5_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p5_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p5_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p5_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p5_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p5_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p5_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p5_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p5_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p5_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p5_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p5_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p5_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p5_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p5_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p5_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p5_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p5_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p5_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p5_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p5_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p5_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p5_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p5_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p5_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p5_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p5_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p5_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p5_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p5_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p5_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p5_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p5_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p5_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p5_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p5_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p5_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p5_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p5_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p5_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p5_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p5_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p5_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p5_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p5_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p5_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p5_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p5_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p5_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p5_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p5_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p5_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p5_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p5_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p5_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p5_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p5_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p5_features['x_arg_diff_Acc'] = abs(    p5_features['x_argmax_Acc'] -     p5_features['x_argmin_Acc'])
p5_features['y_arg_diff_Acc'] = abs(    p5_features['y_argmax_Acc'] -     p5_features['y_argmin_Acc'])
p5_features['z_arg_diff_Acc'] = abs(    p5_features['z_argmax_Acc'] -     p5_features['z_argmin_Acc'])
p5_features['x_arg_diff_Lin'] = abs(    p5_features['x_argmax_Lin'] -     p5_features['x_argmin_Lin'])
p5_features['y_arg_diff_Lin'] = abs(    p5_features['y_argmax_Lin'] -     p5_features['y_argmin_Lin'])
p5_features['z_arg_diff_Lin'] = abs(    p5_features['z_argmax_Lin'] -     p5_features['z_argmin_Lin'])
p5_features['x_arg_diff_Gyro'] = abs(    p5_features['x_argmax_Gyro'] -     p5_features['x_argmin_Gyro'])
p5_features['y_arg_diff_Gyro'] = abs(    p5_features['y_argmax_Gyro'] -     p5_features['y_argmin_Gyro'])
p5_features['z_arg_diff_Gyro'] = abs(    p5_features['z_argmax_Gyro'] -     p5_features['z_argmin_Gyro'])


# index of max value in frequency domain
p5_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p5_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p5_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p5_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p5_features['x_arg_diff_fft_Acc'] = abs(p5_features['x_argmax_fft_Acc'] - p5_features['x_argmin_fft_Acc'])
p5_features['y_arg_diff_fft_Acc'] = abs(p5_features['y_argmax_fft_Acc'] - p5_features['y_argmin_fft_Acc'])
p5_features['z_arg_diff_fft_Acc'] = abs(p5_features['z_argmax_fft_Acc'] - p5_features['z_argmin_fft_Acc'])
p5_features['x_arg_diff_fft_Lin'] = abs(p5_features['x_argmax_fft_Lin'] - p5_features['x_argmin_fft_Lin'])
p5_features['y_arg_diff_fft_Lin'] = abs(p5_features['y_argmax_fft_Lin'] - p5_features['y_argmin_fft_Lin'])
p5_features['z_arg_diff_fft_Lin'] = abs(p5_features['z_argmax_fft_Lin'] - p5_features['z_argmin_fft_Lin'])
p5_features['x_arg_diff_fft_Gyro'] = abs(p5_features['x_argmax_fft_Gyro'] - p5_features['x_argmin_fft_Gyro'])
p5_features['y_arg_diff_fft_Gyro'] = abs(p5_features['y_argmax_fft_Gyro'] - p5_features['y_argmin_fft_Gyro'])
p5_features['z_arg_diff_fft_Gyro'] = abs(p5_features['z_argmax_fft_Gyro'] - p5_features['z_argmin_fft_Gyro'])

p5_features['label_of_activity']=p5_labels

# %%
p5_features
# Out:
#       x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0       2.588999   -8.070916   -1.057136    0.082674   -0.218153    0.096714
# 1       2.651487   -8.067752   -1.059244    0.105678   -0.237809    0.104521
# 2       2.634871   -8.019914   -1.097563    0.043871   -0.202537    0.056097
# 3       2.685445   -8.048665   -1.146270    0.090935   -0.223776    0.029312
# 4       2.696865   -8.038404   -1.178088    0.067155   -0.204234    0.036711
# ...          ...         ...         ...         ...         ...         ...
# 2090    1.995721   -8.044208   -1.337718    0.011442   -0.060101    0.090576
# 2091    2.112040   -8.015986   -1.246825    0.131141   -0.027473    0.181914
# 2092    2.117051   -7.965031   -1.515328    0.045630   -0.027010    0.126128
# 2093    2.200247   -8.071000   -1.343094    0.210642   -0.107480    0.181213
# 2094    2.034643   -7.939794   -1.455162    0.140154    0.020454    0.103849
#
# ...

# %%
# storing the obtained dataframe to csv
p5_features.to_csv('p5_features.csv',index_label='ID')

# %% [markdown]
# # Participant-6

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p6_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p6.shape[0] - window_size, step_size):
    xs_Acc = p6['Acc_x'].values[i: i + 150]
    ys_Acc = p6['Acc_y'].values[i: i + 150]
    zs_Acc = p6['Acc_z'].values[i: i + 150]
    xs_Lin = p6['Lin_x'].values[i: i + 150]
    ys_Lin = p6['Lin_y'].values[i: i + 150]
    zs_Lin = p6['Lin_z'].values[i: i + 150]
    xs_Gyro = p6['Gyro_x'].values[i: i + 150]
    ys_Gyro = p6['Gyro_y'].values[i: i + 150]
    zs_Gyro = p6['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p6['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p6_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p6_features = pd.DataFrame()


# mean
p6_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p6_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p6_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p6_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p6_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p6_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p6_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p6_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p6_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p6_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p6_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p6_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p6_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p6_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p6_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p6_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p6_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p6_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p6_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p6_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p6_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p6_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p6_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p6_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p6_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p6_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p6_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p6_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p6_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p6_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p6_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p6_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p6_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p6_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p6_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p6_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p6_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p6_features['x_maxmin_diff_Acc'] =  p6_features['x_max_Acc'] - p6_features['x_min_Acc']
p6_features['y_maxmin_diff_Acc'] =  p6_features['y_max_Acc'] - p6_features['y_min_Acc']
p6_features['z_maxmin_diff_Acc'] =  p6_features['z_max_Acc'] - p6_features['z_min_Acc']
p6_features['x_maxmin_diff_Lin'] =  p6_features['x_max_Lin'] - p6_features['x_min_Lin']
p6_features['y_maxmin_diff_Lin'] =  p6_features['y_max_Lin'] - p6_features['y_min_Lin']
p6_features['z_maxmin_diff_Lin'] =  p6_features['z_max_Lin'] - p6_features['z_min_Lin']
p6_features['x_maxmin_diff_Gyro'] =  p6_features['x_max_Gyro'] - p6_features['x_min_Gyro']
p6_features['y_maxmin_diff_Gyro'] =  p6_features['y_max_Gyro'] - p6_features['y_min_Gyro']
p6_features['z_maxmin_diff_Gyro'] =  p6_features['z_max_Gyro'] - p6_features['z_min_Gyro']


# median
p6_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p6_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p6_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p6_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p6_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p6_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p6_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p6_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p6_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p6_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p6_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p6_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p6_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p6_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p6_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p6_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p6_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p6_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p6_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p6_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p6_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p6_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p6_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p6_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p6_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p6_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p6_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p6_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p6_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p6_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p6_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p6_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p6_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p6_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p6_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p6_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p6_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p6_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p6_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p6_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p6_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p6_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p6_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p6_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p6_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p6_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p6_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p6_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p6_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p6_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p6_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p6_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p6_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p6_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p6_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p6_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p6_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p6_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p6_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p6_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p6_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p6_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p6_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p6_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p6_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p6_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p6_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p6_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p6_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p6_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p6_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p6_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p6_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p6_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p6_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p6_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p6_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p6_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p6_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p6_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p6_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p6_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p6_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p6_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p6_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p6_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p6_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p6_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p6_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p6_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p6_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p6_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p6_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p6_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p6_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p6_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p6_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p6_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p6_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p6_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p6_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p6_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p6_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p6_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p6_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p6_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p6_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p6_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p6_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p6_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p6_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p6_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p6_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p6_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p6_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p6_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p6_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p6_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p6_features['x_maxmin_diff_fft_Acc'] =     p6_features['x_max_fft_Acc'] - p6_features['x_min_fft_Acc']
p6_features['y_maxmin_diff_fft_Acc'] =     p6_features['y_max_fft_Acc'] - p6_features['y_min_fft_Acc']
p6_features['z_maxmin_diff_fft_Acc'] =     p6_features['z_max_fft_Acc'] - p6_features['z_min_fft_Acc']
p6_features['x_maxmin_diff_fft_Lin'] =     p6_features['x_max_fft_Lin'] - p6_features['x_min_fft_Lin']
p6_features['y_maxmin_diff_fft_Lin'] =     p6_features['y_max_fft_Lin'] - p6_features['y_min_fft_Lin']
p6_features['z_maxmin_diff_fft_Lin'] =     p6_features['z_max_fft_Lin'] - p6_features['z_min_fft_Lin']
p6_features['x_maxmin_diff_fft_Gyro'] =     p6_features['x_max_fft_Gyro'] - p6_features['x_min_fft_Gyro']
p6_features['y_maxmin_diff_fft_Gyro'] =     p6_features['y_max_fft_Gyro'] - p6_features['y_min_fft_Gyro']
p6_features['z_maxmin_diff_fft_Gyro'] =     p6_features['z_max_fft_Gyro'] - p6_features['z_min_fft_Gyro']

# FFT median
p6_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p6_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p6_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p6_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p6_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p6_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p6_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p6_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p6_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p6_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p6_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p6_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p6_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p6_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p6_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p6_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p6_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p6_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p6_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p6_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p6_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p6_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p6_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p6_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p6_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p6_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p6_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p6_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p6_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p6_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p6_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p6_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p6_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p6_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p6_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p6_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p6_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p6_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p6_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p6_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p6_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p6_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p6_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p6_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p6_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p6_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p6_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p6_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p6_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p6_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p6_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p6_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p6_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p6_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p6_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p6_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p6_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p6_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p6_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p6_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p6_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p6_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p6_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p6_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p6_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p6_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p6_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p6_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p6_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p6_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p6_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p6_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p6_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p6_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p6_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p6_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p6_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p6_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p6_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p6_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p6_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p6_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p6_features['x_arg_diff_Acc'] = abs(    p6_features['x_argmax_Acc'] -     p6_features['x_argmin_Acc'])
p6_features['y_arg_diff_Acc'] = abs(    p6_features['y_argmax_Acc'] -     p6_features['y_argmin_Acc'])
p6_features['z_arg_diff_Acc'] = abs(    p6_features['z_argmax_Acc'] -     p6_features['z_argmin_Acc'])
p6_features['x_arg_diff_Lin'] = abs(    p6_features['x_argmax_Lin'] -     p6_features['x_argmin_Lin'])
p6_features['y_arg_diff_Lin'] = abs(    p6_features['y_argmax_Lin'] -     p6_features['y_argmin_Lin'])
p6_features['z_arg_diff_Lin'] = abs(    p6_features['z_argmax_Lin'] -     p6_features['z_argmin_Lin'])
p6_features['x_arg_diff_Gyro'] = abs(    p6_features['x_argmax_Gyro'] -     p6_features['x_argmin_Gyro'])
p6_features['y_arg_diff_Gyro'] = abs(    p6_features['y_argmax_Gyro'] -     p6_features['y_argmin_Gyro'])
p6_features['z_arg_diff_Gyro'] = abs(    p6_features['z_argmax_Gyro'] -     p6_features['z_argmin_Gyro'])


# index of max value in frequency domain
p6_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p6_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p6_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p6_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p6_features['x_arg_diff_fft_Acc'] = abs(p6_features['x_argmax_fft_Acc'] - p6_features['x_argmin_fft_Acc'])
p6_features['y_arg_diff_fft_Acc'] = abs(p6_features['y_argmax_fft_Acc'] - p6_features['y_argmin_fft_Acc'])
p6_features['z_arg_diff_fft_Acc'] = abs(p6_features['z_argmax_fft_Acc'] - p6_features['z_argmin_fft_Acc'])
p6_features['x_arg_diff_fft_Lin'] = abs(p6_features['x_argmax_fft_Lin'] - p6_features['x_argmin_fft_Lin'])
p6_features['y_arg_diff_fft_Lin'] = abs(p6_features['y_argmax_fft_Lin'] - p6_features['y_argmin_fft_Lin'])
p6_features['z_arg_diff_fft_Lin'] = abs(p6_features['z_argmax_fft_Lin'] - p6_features['z_argmin_fft_Lin'])
p6_features['x_arg_diff_fft_Gyro'] = abs(p6_features['x_argmax_fft_Gyro'] - p6_features['x_argmin_fft_Gyro'])
p6_features['y_arg_diff_fft_Gyro'] = abs(p6_features['y_argmax_fft_Gyro'] - p6_features['y_argmin_fft_Gyro'])
p6_features['z_arg_diff_fft_Gyro'] = abs(p6_features['z_argmax_fft_Gyro'] - p6_features['z_argmin_fft_Gyro'])

p6_features['label_of_activity']=p6_labels

# %%
# storing the obtained dataframe to csv
p6_features.to_csv('p6_features.csv',index_label='ID')

# %% [markdown]
# # Features p7

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p7_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p7.shape[0] - window_size, step_size):
    xs_Acc = p7['Acc_x'].values[i: i + 100]
    ys_Acc = p7['Acc_y'].values[i: i + 100]
    zs_Acc = p7['Acc_z'].values[i: i + 100]
    xs_Lin = p7['Lin_x'].values[i: i + 100]
    ys_Lin = p7['Lin_y'].values[i: i + 100]
    zs_Lin = p7['Lin_z'].values[i: i + 100]
    xs_Gyro = p7['Gyro_x'].values[i: i + 100]
    ys_Gyro = p7['Gyro_y'].values[i: i + 100]
    zs_Gyro = p7['Gyro_z'].values[i: i + 100]
    label_of_activity = stats.mode(p7['label_of_activity'][i: i + 100])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p7_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p7_features = pd.DataFrame()


# mean
p7_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p7_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p7_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p7_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p7_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p7_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p7_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p7_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p7_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p7_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p7_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p7_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p7_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p7_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p7_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p7_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p7_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p7_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p7_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p7_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p7_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p7_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p7_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p7_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p7_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p7_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p7_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p7_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p7_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p7_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p7_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p7_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p7_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p7_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p7_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p7_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p7_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p7_features['x_maxmin_diff_Acc'] =  p7_features['x_max_Acc'] - p7_features['x_min_Acc']
p7_features['y_maxmin_diff_Acc'] =  p7_features['y_max_Acc'] - p7_features['y_min_Acc']
p7_features['z_maxmin_diff_Acc'] =  p7_features['z_max_Acc'] - p7_features['z_min_Acc']
p7_features['x_maxmin_diff_Lin'] =  p7_features['x_max_Lin'] - p7_features['x_min_Lin']
p7_features['y_maxmin_diff_Lin'] =  p7_features['y_max_Lin'] - p7_features['y_min_Lin']
p7_features['z_maxmin_diff_Lin'] =  p7_features['z_max_Lin'] - p7_features['z_min_Lin']
p7_features['x_maxmin_diff_Gyro'] =  p7_features['x_max_Gyro'] - p7_features['x_min_Gyro']
p7_features['y_maxmin_diff_Gyro'] =  p7_features['y_max_Gyro'] - p7_features['y_min_Gyro']
p7_features['z_maxmin_diff_Gyro'] =  p7_features['z_max_Gyro'] - p7_features['z_min_Gyro']


# median
p7_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p7_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p7_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p7_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p7_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p7_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p7_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p7_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p7_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p7_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p7_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p7_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p7_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p7_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p7_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p7_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p7_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p7_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p7_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p7_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p7_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p7_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p7_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p7_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p7_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p7_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p7_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p7_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p7_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p7_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p7_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p7_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p7_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p7_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p7_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p7_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p7_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p7_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p7_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p7_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p7_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p7_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p7_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p7_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p7_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p7_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p7_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p7_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p7_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p7_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p7_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p7_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p7_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p7_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p7_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p7_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p7_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p7_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p7_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p7_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p7_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p7_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p7_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p7_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p7_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p7_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/100)
p7_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/100)
p7_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/100)
p7_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/100)
p7_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/100)
p7_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/100)
p7_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/100)
p7_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/100)
p7_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/100)

# avg resultant
p7_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p7_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p7_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p7_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/100)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/100)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/100))
p7_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/100)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/100)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/100))
p7_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/100)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/100)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/100))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p7_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p7_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p7_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p7_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p7_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p7_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p7_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p7_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p7_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p7_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p7_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p7_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p7_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p7_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p7_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p7_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p7_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p7_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p7_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p7_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p7_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p7_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p7_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p7_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p7_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p7_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p7_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p7_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p7_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p7_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p7_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p7_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p7_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p7_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p7_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p7_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p7_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p7_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p7_features['x_maxmin_diff_fft_Acc'] =     p7_features['x_max_fft_Acc'] - p7_features['x_min_fft_Acc']
p7_features['y_maxmin_diff_fft_Acc'] =     p7_features['y_max_fft_Acc'] - p7_features['y_min_fft_Acc']
p7_features['z_maxmin_diff_fft_Acc'] =     p7_features['z_max_fft_Acc'] - p7_features['z_min_fft_Acc']
p7_features['x_maxmin_diff_fft_Lin'] =     p7_features['x_max_fft_Lin'] - p7_features['x_min_fft_Lin']
p7_features['y_maxmin_diff_fft_Lin'] =     p7_features['y_max_fft_Lin'] - p7_features['y_min_fft_Lin']
p7_features['z_maxmin_diff_fft_Lin'] =     p7_features['z_max_fft_Lin'] - p7_features['z_min_fft_Lin']
p7_features['x_maxmin_diff_fft_Gyro'] =     p7_features['x_max_fft_Gyro'] - p7_features['x_min_fft_Gyro']
p7_features['y_maxmin_diff_fft_Gyro'] =     p7_features['y_max_fft_Gyro'] - p7_features['y_min_fft_Gyro']
p7_features['z_maxmin_diff_fft_Gyro'] =     p7_features['z_max_fft_Gyro'] - p7_features['z_min_fft_Gyro']

# FFT median
p7_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p7_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p7_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p7_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p7_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p7_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p7_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p7_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p7_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p7_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p7_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p7_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p7_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p7_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p7_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p7_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p7_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p7_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p7_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p7_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p7_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p7_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p7_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p7_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p7_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p7_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p7_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p7_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p7_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p7_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p7_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p7_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p7_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p7_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p7_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p7_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p7_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p7_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p7_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p7_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p7_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p7_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p7_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p7_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p7_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p7_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p7_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p7_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p7_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p7_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p7_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p7_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p7_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p7_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p7_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p7_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p7_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p7_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p7_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p7_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p7_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p7_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p7_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p7_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p7_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p7_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p7_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p7_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p7_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p7_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p7_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p7_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p7_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p7_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p7_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p7_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p7_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p7_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p7_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p7_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p7_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p7_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p7_features['x_arg_diff_Acc'] = abs(    p7_features['x_argmax_Acc'] -     p7_features['x_argmin_Acc'])
p7_features['y_arg_diff_Acc'] = abs(    p7_features['y_argmax_Acc'] -     p7_features['y_argmin_Acc'])
p7_features['z_arg_diff_Acc'] = abs(    p7_features['z_argmax_Acc'] -     p7_features['z_argmin_Acc'])
p7_features['x_arg_diff_Lin'] = abs(    p7_features['x_argmax_Lin'] -     p7_features['x_argmin_Lin'])
p7_features['y_arg_diff_Lin'] = abs(    p7_features['y_argmax_Lin'] -     p7_features['y_argmin_Lin'])
p7_features['z_arg_diff_Lin'] = abs(    p7_features['z_argmax_Lin'] -     p7_features['z_argmin_Lin'])
p7_features['x_arg_diff_Gyro'] = abs(    p7_features['x_argmax_Gyro'] -     p7_features['x_argmin_Gyro'])
p7_features['y_arg_diff_Gyro'] = abs(    p7_features['y_argmax_Gyro'] -     p7_features['y_argmin_Gyro'])
p7_features['z_arg_diff_Gyro'] = abs(    p7_features['z_argmax_Gyro'] -     p7_features['z_argmin_Gyro'])


# index of max value in frequency domain
p7_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p7_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p7_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p7_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p7_features['x_arg_diff_fft_Acc'] = abs(p7_features['x_argmax_fft_Acc'] - p7_features['x_argmin_fft_Acc'])
p7_features['y_arg_diff_fft_Acc'] = abs(p7_features['y_argmax_fft_Acc'] - p7_features['y_argmin_fft_Acc'])
p7_features['z_arg_diff_fft_Acc'] = abs(p7_features['z_argmax_fft_Acc'] - p7_features['z_argmin_fft_Acc'])
p7_features['x_arg_diff_fft_Lin'] = abs(p7_features['x_argmax_fft_Lin'] - p7_features['x_argmin_fft_Lin'])
p7_features['y_arg_diff_fft_Lin'] = abs(p7_features['y_argmax_fft_Lin'] - p7_features['y_argmin_fft_Lin'])
p7_features['z_arg_diff_fft_Lin'] = abs(p7_features['z_argmax_fft_Lin'] - p7_features['z_argmin_fft_Lin'])
p7_features['x_arg_diff_fft_Gyro'] = abs(p7_features['x_argmax_fft_Gyro'] - p7_features['x_argmin_fft_Gyro'])
p7_features['y_arg_diff_fft_Gyro'] = abs(p7_features['y_argmax_fft_Gyro'] - p7_features['y_argmin_fft_Gyro'])
p7_features['z_arg_diff_fft_Gyro'] = abs(p7_features['z_argmax_fft_Gyro'] - p7_features['z_argmin_fft_Gyro'])

p7_features['label_of_activity']=p7_labels

# storing the obtained dataframe to csv
p7_features.to_csv('p7_features.csv',index_label='ID')

# %% [markdown]
# # Features p8

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p8_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p8.shape[0] - window_size, step_size):
    xs_Acc = p8['Acc_x'].values[i: i + 150]
    ys_Acc = p8['Acc_y'].values[i: i + 150]
    zs_Acc = p8['Acc_z'].values[i: i + 150]
    xs_Lin = p8['Lin_x'].values[i: i + 150]
    ys_Lin = p8['Lin_y'].values[i: i + 150]
    zs_Lin = p8['Lin_z'].values[i: i + 150]
    xs_Gyro = p8['Gyro_x'].values[i: i + 150]
    ys_Gyro = p8['Gyro_y'].values[i: i + 150]
    zs_Gyro = p8['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p8['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p8_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p8_features = pd.DataFrame()


# mean
p8_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p8_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p8_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p8_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p8_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p8_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p8_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p8_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p8_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p8_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p8_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p8_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p8_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p8_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p8_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p8_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p8_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p8_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p8_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p8_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p8_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p8_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p8_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p8_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p8_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p8_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p8_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p8_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p8_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p8_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p8_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p8_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p8_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p8_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p8_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p8_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p8_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p8_features['x_maxmin_diff_Acc'] =  p8_features['x_max_Acc'] - p8_features['x_min_Acc']
p8_features['y_maxmin_diff_Acc'] =  p8_features['y_max_Acc'] - p8_features['y_min_Acc']
p8_features['z_maxmin_diff_Acc'] =  p8_features['z_max_Acc'] - p8_features['z_min_Acc']
p8_features['x_maxmin_diff_Lin'] =  p8_features['x_max_Lin'] - p8_features['x_min_Lin']
p8_features['y_maxmin_diff_Lin'] =  p8_features['y_max_Lin'] - p8_features['y_min_Lin']
p8_features['z_maxmin_diff_Lin'] =  p8_features['z_max_Lin'] - p8_features['z_min_Lin']
p8_features['x_maxmin_diff_Gyro'] =  p8_features['x_max_Gyro'] - p8_features['x_min_Gyro']
p8_features['y_maxmin_diff_Gyro'] =  p8_features['y_max_Gyro'] - p8_features['y_min_Gyro']
p8_features['z_maxmin_diff_Gyro'] =  p8_features['z_max_Gyro'] - p8_features['z_min_Gyro']


# median
p8_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p8_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p8_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p8_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p8_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p8_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p8_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p8_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p8_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p8_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p8_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p8_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p8_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p8_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p8_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p8_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p8_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p8_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p8_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p8_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p8_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p8_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p8_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p8_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p8_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p8_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p8_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p8_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p8_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p8_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p8_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p8_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p8_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p8_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p8_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p8_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p8_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p8_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p8_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p8_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p8_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p8_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p8_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p8_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p8_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p8_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p8_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p8_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p8_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p8_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p8_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p8_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p8_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p8_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p8_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p8_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p8_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p8_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p8_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p8_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p8_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p8_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p8_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p8_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p8_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p8_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p8_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p8_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p8_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p8_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p8_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p8_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p8_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p8_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p8_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p8_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p8_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p8_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p8_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p8_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p8_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p8_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p8_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p8_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p8_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p8_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p8_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p8_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p8_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p8_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p8_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p8_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p8_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p8_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p8_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p8_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p8_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p8_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p8_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p8_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p8_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p8_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p8_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p8_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p8_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p8_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p8_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p8_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p8_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p8_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p8_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p8_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p8_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p8_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p8_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p8_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p8_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p8_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p8_features['x_maxmin_diff_fft_Acc'] =     p8_features['x_max_fft_Acc'] - p8_features['x_min_fft_Acc']
p8_features['y_maxmin_diff_fft_Acc'] =     p8_features['y_max_fft_Acc'] - p8_features['y_min_fft_Acc']
p8_features['z_maxmin_diff_fft_Acc'] =     p8_features['z_max_fft_Acc'] - p8_features['z_min_fft_Acc']
p8_features['x_maxmin_diff_fft_Lin'] =     p8_features['x_max_fft_Lin'] - p8_features['x_min_fft_Lin']
p8_features['y_maxmin_diff_fft_Lin'] =     p8_features['y_max_fft_Lin'] - p8_features['y_min_fft_Lin']
p8_features['z_maxmin_diff_fft_Lin'] =     p8_features['z_max_fft_Lin'] - p8_features['z_min_fft_Lin']
p8_features['x_maxmin_diff_fft_Gyro'] =     p8_features['x_max_fft_Gyro'] - p8_features['x_min_fft_Gyro']
p8_features['y_maxmin_diff_fft_Gyro'] =     p8_features['y_max_fft_Gyro'] - p8_features['y_min_fft_Gyro']
p8_features['z_maxmin_diff_fft_Gyro'] =     p8_features['z_max_fft_Gyro'] - p8_features['z_min_fft_Gyro']

# FFT median
p8_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p8_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p8_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p8_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p8_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p8_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p8_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p8_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p8_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p8_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p8_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p8_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p8_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p8_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p8_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p8_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p8_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p8_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p8_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p8_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p8_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p8_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p8_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p8_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p8_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p8_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p8_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p8_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p8_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p8_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p8_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p8_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p8_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p8_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p8_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p8_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p8_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p8_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p8_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p8_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p8_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p8_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p8_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p8_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p8_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p8_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p8_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p8_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p8_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p8_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p8_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p8_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p8_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p8_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p8_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p8_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p8_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p8_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p8_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p8_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p8_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p8_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p8_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p8_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p8_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p8_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p8_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p8_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p8_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p8_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p8_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p8_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p8_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p8_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p8_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p8_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p8_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p8_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p8_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p8_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p8_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p8_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p8_features['x_arg_diff_Acc'] = abs(    p8_features['x_argmax_Acc'] -     p8_features['x_argmin_Acc'])
p8_features['y_arg_diff_Acc'] = abs(    p8_features['y_argmax_Acc'] -     p8_features['y_argmin_Acc'])
p8_features['z_arg_diff_Acc'] = abs(    p8_features['z_argmax_Acc'] -     p8_features['z_argmin_Acc'])
p8_features['x_arg_diff_Lin'] = abs(    p8_features['x_argmax_Lin'] -     p8_features['x_argmin_Lin'])
p8_features['y_arg_diff_Lin'] = abs(    p8_features['y_argmax_Lin'] -     p8_features['y_argmin_Lin'])
p8_features['z_arg_diff_Lin'] = abs(    p8_features['z_argmax_Lin'] -     p8_features['z_argmin_Lin'])
p8_features['x_arg_diff_Gyro'] = abs(    p8_features['x_argmax_Gyro'] -     p8_features['x_argmin_Gyro'])
p8_features['y_arg_diff_Gyro'] = abs(    p8_features['y_argmax_Gyro'] -     p8_features['y_argmin_Gyro'])
p8_features['z_arg_diff_Gyro'] = abs(    p8_features['z_argmax_Gyro'] -     p8_features['z_argmin_Gyro'])


# index of max value in frequency domain
p8_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p8_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p8_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p8_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p8_features['x_arg_diff_fft_Acc'] = abs(p8_features['x_argmax_fft_Acc'] - p8_features['x_argmin_fft_Acc'])
p8_features['y_arg_diff_fft_Acc'] = abs(p8_features['y_argmax_fft_Acc'] - p8_features['y_argmin_fft_Acc'])
p8_features['z_arg_diff_fft_Acc'] = abs(p8_features['z_argmax_fft_Acc'] - p8_features['z_argmin_fft_Acc'])
p8_features['x_arg_diff_fft_Lin'] = abs(p8_features['x_argmax_fft_Lin'] - p8_features['x_argmin_fft_Lin'])
p8_features['y_arg_diff_fft_Lin'] = abs(p8_features['y_argmax_fft_Lin'] - p8_features['y_argmin_fft_Lin'])
p8_features['z_arg_diff_fft_Lin'] = abs(p8_features['z_argmax_fft_Lin'] - p8_features['z_argmin_fft_Lin'])
p8_features['x_arg_diff_fft_Gyro'] = abs(p8_features['x_argmax_fft_Gyro'] - p8_features['x_argmin_fft_Gyro'])
p8_features['y_arg_diff_fft_Gyro'] = abs(p8_features['y_argmax_fft_Gyro'] - p8_features['y_argmin_fft_Gyro'])
p8_features['z_arg_diff_fft_Gyro'] = abs(p8_features['z_argmax_fft_Gyro'] - p8_features['z_argmin_fft_Gyro'])

p8_features['label_of_activity']=p8_labels

# storing the obtained dataframe to csv
p8_features.to_csv('p8_features.csv',index_label='ID')

# %% [markdown]
# # Features p9

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p9_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p9.shape[0] - window_size, step_size):
    xs_Acc = p9['Acc_x'].values[i: i + 150]
    ys_Acc = p9['Acc_y'].values[i: i + 150]
    zs_Acc = p9['Acc_z'].values[i: i + 150]
    xs_Lin = p9['Lin_x'].values[i: i + 150]
    ys_Lin = p9['Lin_y'].values[i: i + 150]
    zs_Lin = p9['Lin_z'].values[i: i + 150]
    xs_Gyro = p9['Gyro_x'].values[i: i + 150]
    ys_Gyro = p9['Gyro_y'].values[i: i + 150]
    zs_Gyro = p9['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p9['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p9_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p9_features = pd.DataFrame()


# mean
p9_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p9_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p9_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p9_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p9_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p9_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p9_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p9_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p9_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p9_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p9_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p9_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p9_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p9_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p9_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p9_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p9_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p9_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p9_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p9_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p9_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p9_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p9_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p9_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p9_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p9_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p9_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p9_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p9_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p9_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p9_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p9_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p9_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p9_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p9_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p9_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p9_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p9_features['x_maxmin_diff_Acc'] =  p9_features['x_max_Acc'] - p9_features['x_min_Acc']
p9_features['y_maxmin_diff_Acc'] =  p9_features['y_max_Acc'] - p9_features['y_min_Acc']
p9_features['z_maxmin_diff_Acc'] =  p9_features['z_max_Acc'] - p9_features['z_min_Acc']
p9_features['x_maxmin_diff_Lin'] =  p9_features['x_max_Lin'] - p9_features['x_min_Lin']
p9_features['y_maxmin_diff_Lin'] =  p9_features['y_max_Lin'] - p9_features['y_min_Lin']
p9_features['z_maxmin_diff_Lin'] =  p9_features['z_max_Lin'] - p9_features['z_min_Lin']
p9_features['x_maxmin_diff_Gyro'] =  p9_features['x_max_Gyro'] - p9_features['x_min_Gyro']
p9_features['y_maxmin_diff_Gyro'] =  p9_features['y_max_Gyro'] - p9_features['y_min_Gyro']
p9_features['z_maxmin_diff_Gyro'] =  p9_features['z_max_Gyro'] - p9_features['z_min_Gyro']


# median
p9_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p9_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p9_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p9_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p9_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p9_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p9_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p9_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p9_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p9_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p9_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p9_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p9_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p9_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p9_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p9_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p9_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p9_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p9_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p9_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p9_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p9_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p9_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p9_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p9_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p9_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p9_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p9_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p9_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p9_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p9_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p9_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p9_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p9_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p9_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p9_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p9_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p9_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p9_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p9_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p9_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p9_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p9_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p9_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p9_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p9_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p9_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p9_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p9_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p9_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p9_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p9_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p9_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p9_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p9_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p9_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p9_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p9_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p9_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p9_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p9_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p9_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p9_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p9_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p9_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p9_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p9_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p9_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p9_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p9_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p9_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p9_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p9_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p9_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p9_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p9_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p9_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p9_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p9_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p9_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p9_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p9_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p9_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p9_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p9_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p9_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p9_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p9_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p9_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p9_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p9_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p9_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p9_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p9_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p9_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p9_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p9_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p9_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p9_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p9_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p9_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p9_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p9_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p9_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p9_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p9_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p9_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p9_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p9_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p9_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p9_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p9_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p9_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p9_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p9_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p9_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p9_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p9_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p9_features['x_maxmin_diff_fft_Acc'] =     p9_features['x_max_fft_Acc'] - p9_features['x_min_fft_Acc']
p9_features['y_maxmin_diff_fft_Acc'] =     p9_features['y_max_fft_Acc'] - p9_features['y_min_fft_Acc']
p9_features['z_maxmin_diff_fft_Acc'] =     p9_features['z_max_fft_Acc'] - p9_features['z_min_fft_Acc']
p9_features['x_maxmin_diff_fft_Lin'] =     p9_features['x_max_fft_Lin'] - p9_features['x_min_fft_Lin']
p9_features['y_maxmin_diff_fft_Lin'] =     p9_features['y_max_fft_Lin'] - p9_features['y_min_fft_Lin']
p9_features['z_maxmin_diff_fft_Lin'] =     p9_features['z_max_fft_Lin'] - p9_features['z_min_fft_Lin']
p9_features['x_maxmin_diff_fft_Gyro'] =     p9_features['x_max_fft_Gyro'] - p9_features['x_min_fft_Gyro']
p9_features['y_maxmin_diff_fft_Gyro'] =     p9_features['y_max_fft_Gyro'] - p9_features['y_min_fft_Gyro']
p9_features['z_maxmin_diff_fft_Gyro'] =     p9_features['z_max_fft_Gyro'] - p9_features['z_min_fft_Gyro']

# FFT median
p9_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p9_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p9_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p9_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p9_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p9_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p9_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p9_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p9_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p9_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p9_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p9_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p9_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p9_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p9_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p9_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p9_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p9_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p9_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p9_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p9_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p9_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p9_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p9_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p9_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p9_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p9_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p9_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p9_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p9_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p9_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p9_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p9_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p9_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p9_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p9_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p9_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p9_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p9_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p9_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p9_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p9_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p9_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p9_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p9_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p9_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p9_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p9_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p9_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p9_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p9_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p9_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p9_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p9_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p9_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p9_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p9_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p9_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p9_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p9_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p9_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p9_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p9_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p9_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p9_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p9_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p9_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p9_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p9_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p9_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p9_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p9_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p9_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p9_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p9_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p9_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p9_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p9_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p9_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p9_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p9_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p9_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p9_features['x_arg_diff_Acc'] = abs(    p9_features['x_argmax_Acc'] -     p9_features['x_argmin_Acc'])
p9_features['y_arg_diff_Acc'] = abs(    p9_features['y_argmax_Acc'] -     p9_features['y_argmin_Acc'])
p9_features['z_arg_diff_Acc'] = abs(    p9_features['z_argmax_Acc'] -     p9_features['z_argmin_Acc'])
p9_features['x_arg_diff_Lin'] = abs(    p9_features['x_argmax_Lin'] -     p9_features['x_argmin_Lin'])
p9_features['y_arg_diff_Lin'] = abs(    p9_features['y_argmax_Lin'] -     p9_features['y_argmin_Lin'])
p9_features['z_arg_diff_Lin'] = abs(    p9_features['z_argmax_Lin'] -     p9_features['z_argmin_Lin'])
p9_features['x_arg_diff_Gyro'] = abs(    p9_features['x_argmax_Gyro'] -     p9_features['x_argmin_Gyro'])
p9_features['y_arg_diff_Gyro'] = abs(    p9_features['y_argmax_Gyro'] -     p9_features['y_argmin_Gyro'])
p9_features['z_arg_diff_Gyro'] = abs(    p9_features['z_argmax_Gyro'] -     p9_features['z_argmin_Gyro'])


# index of max value in frequency domain
p9_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p9_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p9_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p9_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p9_features['x_arg_diff_fft_Acc'] = abs(p9_features['x_argmax_fft_Acc'] - p9_features['x_argmin_fft_Acc'])
p9_features['y_arg_diff_fft_Acc'] = abs(p9_features['y_argmax_fft_Acc'] - p9_features['y_argmin_fft_Acc'])
p9_features['z_arg_diff_fft_Acc'] = abs(p9_features['z_argmax_fft_Acc'] - p9_features['z_argmin_fft_Acc'])
p9_features['x_arg_diff_fft_Lin'] = abs(p9_features['x_argmax_fft_Lin'] - p9_features['x_argmin_fft_Lin'])
p9_features['y_arg_diff_fft_Lin'] = abs(p9_features['y_argmax_fft_Lin'] - p9_features['y_argmin_fft_Lin'])
p9_features['z_arg_diff_fft_Lin'] = abs(p9_features['z_argmax_fft_Lin'] - p9_features['z_argmin_fft_Lin'])
p9_features['x_arg_diff_fft_Gyro'] = abs(p9_features['x_argmax_fft_Gyro'] - p9_features['x_argmin_fft_Gyro'])
p9_features['y_arg_diff_fft_Gyro'] = abs(p9_features['y_argmax_fft_Gyro'] - p9_features['y_argmin_fft_Gyro'])
p9_features['z_arg_diff_fft_Gyro'] = abs(p9_features['z_argmax_fft_Gyro'] - p9_features['z_argmin_fft_Gyro'])

p9_features['label_of_activity']=p9_labels

# storing the obtained dataframe to csv
p9_features.to_csv('p9_features.csv',index_label='ID')

# %% [markdown]
# # Features p10

# %%
# creating 20% overlaping windows of size window-size 130 (3 second window)
x_list_Acc = []
y_list_Acc = []
z_list_Acc = []
x_list_Lin = []
y_list_Lin = []
z_list_Lin = []
x_list_Gyro = []
y_list_Gyro = []
z_list_Gyro = []
p10_labels = []

# making window with 20% overlapping
window_size = 150
step_size = 30  

for i in range(0, p10.shape[0] - window_size, step_size):
    xs_Acc = p10['Acc_x'].values[i: i + 150]
    ys_Acc = p10['Acc_y'].values[i: i + 150]
    zs_Acc = p10['Acc_z'].values[i: i + 150]
    xs_Lin = p10['Lin_x'].values[i: i + 150]
    ys_Lin = p10['Lin_y'].values[i: i + 150]
    zs_Lin = p10['Lin_z'].values[i: i + 150]
    xs_Gyro = p10['Gyro_x'].values[i: i + 150]
    ys_Gyro = p10['Gyro_y'].values[i: i + 150]
    zs_Gyro = p10['Gyro_z'].values[i: i + 150]
    label_of_activity = stats.mode(p10['label_of_activity'][i: i + 150])[0][0]

    x_list_Acc.append(xs_Acc)
    y_list_Acc.append(ys_Acc)
    z_list_Acc.append(zs_Acc)
    x_list_Lin.append(xs_Lin)
    y_list_Lin.append(ys_Lin)
    z_list_Lin.append(zs_Lin)
    x_list_Gyro.append(xs_Gyro)
    y_list_Gyro.append(ys_Gyro)
    z_list_Gyro.append(zs_Gyro)
    p10_labels.append(label_of_activity)

# Statistical Features on raw x, y and z in time domain
p10_features = pd.DataFrame()


# mean
p10_features['x_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.mean())
p10_features['y_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.mean())
p10_features['z_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.mean())
p10_features['x_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.mean())
p10_features['y_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.mean())
p10_features['z_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.mean())
p10_features['x_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.mean())
p10_features['y_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.mean())
p10_features['z_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.mean())

# std dev
p10_features['x_std_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.std())
p10_features['y_std_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.std())
p10_features['z_std_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.std())
p10_features['x_std_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.std())
p10_features['y_std_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.std())
p10_features['z_std_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.std())
p10_features['x_std_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.std())
p10_features['y_std_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.std())
p10_features['z_std_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.std())

# avg absolute diff
p10_features['x_aad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['y_aad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['z_aad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['x_aad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['y_aad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['z_aad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['x_aad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['y_aad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['z_aad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))


# min
p10_features['x_min_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.min())
p10_features['y_min_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.min())
p10_features['z_min_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.min())
p10_features['x_min_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.min())
p10_features['y_min_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.min())
p10_features['z_min_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.min())
p10_features['x_min_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.min())
p10_features['y_min_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.min())
p10_features['z_min_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.min())

# max
p10_features['x_max_Acc'] = pd.Series(x_list_Acc).apply(lambda x: x.max())
p10_features['y_max_Acc'] = pd.Series(y_list_Acc).apply(lambda x: x.max())
p10_features['z_max_Acc'] = pd.Series(z_list_Acc).apply(lambda x: x.max())
p10_features['x_max_Lin'] = pd.Series(x_list_Lin).apply(lambda x: x.max())
p10_features['y_max_Lin'] = pd.Series(y_list_Lin).apply(lambda x: x.max())
p10_features['z_max_Lin'] = pd.Series(z_list_Lin).apply(lambda x: x.max())
p10_features['x_max_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: x.max())
p10_features['y_max_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: x.max())
p10_features['z_max_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: x.max())

# max-min diff
p10_features['x_maxmin_diff_Acc'] =  p10_features['x_max_Acc'] - p10_features['x_min_Acc']
p10_features['y_maxmin_diff_Acc'] =  p10_features['y_max_Acc'] - p10_features['y_min_Acc']
p10_features['z_maxmin_diff_Acc'] =  p10_features['z_max_Acc'] - p10_features['z_min_Acc']
p10_features['x_maxmin_diff_Lin'] =  p10_features['x_max_Lin'] - p10_features['x_min_Lin']
p10_features['y_maxmin_diff_Lin'] =  p10_features['y_max_Lin'] - p10_features['y_min_Lin']
p10_features['z_maxmin_diff_Lin'] =  p10_features['z_max_Lin'] - p10_features['z_min_Lin']
p10_features['x_maxmin_diff_Gyro'] =  p10_features['x_max_Gyro'] - p10_features['x_min_Gyro']
p10_features['y_maxmin_diff_Gyro'] =  p10_features['y_max_Gyro'] - p10_features['y_min_Gyro']
p10_features['z_maxmin_diff_Gyro'] =  p10_features['z_max_Gyro'] - p10_features['z_min_Gyro']


# median
p10_features['x_median_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(x))
p10_features['y_median_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(x))
p10_features['z_median_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(x))
p10_features['x_median_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(x))
p10_features['y_median_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(x))
p10_features['z_median_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(x))
p10_features['x_median_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(x))
p10_features['y_median_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(x))
p10_features['z_median_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(x))


# median abs dev 
p10_features['x_mad_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['y_mad_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['z_mad_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['x_mad_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['y_mad_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['z_mad_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['x_mad_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['y_mad_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['z_mad_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))



# interquartile range
p10_features['x_IQR_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['y_IQR_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['z_IQR_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['x_IQR_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['y_IQR_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['z_IQR_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['x_IQR_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['y_IQR_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['z_IQR_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

# negtive count
p10_features['x_neg_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x < 0))
p10_features['y_neg_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x < 0))
p10_features['z_neg_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x < 0))
p10_features['x_neg_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x < 0))
p10_features['y_neg_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x < 0))
p10_features['z_neg_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x < 0))
p10_features['x_neg_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x < 0))
p10_features['y_neg_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x < 0))
p10_features['z_neg_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x < 0))

# positive count
p10_features['x_pos_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > 0))
p10_features['y_pos_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > 0))
p10_features['z_pos_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > 0))
p10_features['x_pos_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > 0))
p10_features['y_pos_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > 0))
p10_features['z_pos_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > 0))
p10_features['x_pos_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > 0))
p10_features['y_pos_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > 0))
p10_features['z_pos_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > 0))

# values above mean
p10_features['x_above_mean_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p10_features['y_above_mean_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p10_features['z_above_mean_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x > x.mean()))
p10_features['x_above_mean_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p10_features['y_above_mean_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p10_features['z_above_mean_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x > x.mean()))
p10_features['x_above_mean_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p10_features['y_above_mean_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x > x.mean()))
p10_features['z_above_mean_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x > x.mean()))

# number of peaks
p10_features['x_peak_count_Acc'] = pd.Series(x_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p10_features['y_peak_count_Acc'] = pd.Series(y_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p10_features['z_peak_count_Acc'] = pd.Series(z_list_Acc).apply(lambda x: len(find_peaks(x)[0]))
p10_features['x_peak_count_Lin'] = pd.Series(x_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p10_features['y_peak_count_Lin'] = pd.Series(y_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p10_features['z_peak_count_Lin'] = pd.Series(z_list_Lin).apply(lambda x: len(find_peaks(x)[0]))
p10_features['x_peak_count_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p10_features['y_peak_count_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p10_features['z_peak_count_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: len(find_peaks(x)[0]))

# skewness
p10_features['x_skewness_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.skew(x))
p10_features['y_skewness_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.skew(x))
p10_features['z_skewness_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.skew(x))
p10_features['x_skewness_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.skew(x))
p10_features['y_skewness_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.skew(x))
p10_features['z_skewness_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.skew(x))
p10_features['x_skewness_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.skew(x))
p10_features['y_skewness_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.skew(x))
p10_features['z_skewness_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.skew(x))


# kurtosis
p10_features['x_kurtosis_Acc'] = pd.Series(x_list_Acc).apply(lambda x: stats.kurtosis(x))
p10_features['y_kurtosis_Acc'] = pd.Series(y_list_Acc).apply(lambda x: stats.kurtosis(x))
p10_features['z_kurtosis_Acc'] = pd.Series(z_list_Acc).apply(lambda x: stats.kurtosis(x))
p10_features['x_kurtosis_Lin'] = pd.Series(x_list_Lin).apply(lambda x: stats.kurtosis(x))
p10_features['y_kurtosis_Lin'] = pd.Series(y_list_Lin).apply(lambda x: stats.kurtosis(x))
p10_features['z_kurtosis_Lin'] = pd.Series(z_list_Lin).apply(lambda x: stats.kurtosis(x))
p10_features['x_kurtosis_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: stats.kurtosis(x))
p10_features['y_kurtosis_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: stats.kurtosis(x))
p10_features['z_kurtosis_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: stats.kurtosis(x))

# energy
p10_features['x_energy_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.sum(x**2)/150)
p10_features['y_energy_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.sum(x**2)/150)
p10_features['z_energy_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.sum(x**2)/150)
p10_features['x_energy_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.sum(x**2)/150)
p10_features['y_energy_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.sum(x**2)/150)
p10_features['z_energy_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.sum(x**2)/150)
p10_features['x_energy_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p10_features['y_energy_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.sum(x**2)/150)
p10_features['z_energy_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.sum(x**2)/150)

# avg resultant
p10_features['avg_result_Acc'] = [i.mean() for i in ((pd.Series(x_list_Acc)**2 + pd.Series(y_list_Acc)**2 + pd.Series(z_list_Acc)**2)**0.5)]
p10_features['avg_result_Lin'] = [i.mean() for i in ((pd.Series(x_list_Lin)**2 + pd.Series(y_list_Lin)**2 + pd.Series(z_list_Lin)**2)**0.5)]
p10_features['avg_result_Gyro'] = [i.mean() for i in ((pd.Series(x_list_Gyro)**2 + pd.Series(y_list_Gyro)**2 + pd.Series(z_list_Gyro)**2)**0.5)]


# signal magnitude area
p10_features['sma_Acc'] =    pd.Series(x_list_Acc).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Acc).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Acc).apply(lambda x: np.sum(abs(x)/150))
p10_features['sma_Lin'] =    pd.Series(x_list_Lin).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Lin).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Lin).apply(lambda x: np.sum(abs(x)/150))
p10_features['sma_Gyro'] =    pd.Series(x_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) + pd.Series(y_list_Gyro).apply(lambda x: np.sum(abs(x)/150)) \
              + pd.Series(z_list_Gyro).apply(lambda x: np.sum(abs(x)/150))


# converting the signals from time domain to frequency domain using FFT
x_list_fft_Acc = pd.Series(x_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Acc = pd.Series(y_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Acc = pd.Series(z_list_Acc).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Lin = pd.Series(x_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Lin = pd.Series(y_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Lin = pd.Series(z_list_Lin).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
x_list_fft_Gyro = pd.Series(x_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
y_list_fft_Gyro = pd.Series(y_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])
z_list_fft_Gyro = pd.Series(z_list_Gyro).apply(lambda x: np.abs(np.fft.fft(x))[1:31])



# Statistical Features on raw x, y and z in frequency domain
# FFT mean
p10_features['x_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.mean())
p10_features['y_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.mean())
p10_features['z_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.mean())
p10_features['x_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.mean())
p10_features['y_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.mean())
p10_features['z_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.mean())
p10_features['x_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.mean())
p10_features['y_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.mean())
p10_features['z_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.mean())

# FFT std dev
p10_features['x_std_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.std())
p10_features['y_std_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.std())
p10_features['z_std_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.std())
p10_features['x_std_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.std())
p10_features['y_std_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.std())
p10_features['z_std_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.std())
p10_features['x_std_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.std())
p10_features['y_std_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.std())
p10_features['z_std_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.std())

# FFT avg absolute diff
p10_features['x_aad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['y_aad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['z_aad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['x_aad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['y_aad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['z_aad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['x_aad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['y_aad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
p10_features['z_aad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

# FFT min
p10_features['x_min_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.min())
p10_features['y_min_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.min())
p10_features['z_min_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.min())
p10_features['x_min_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.min())
p10_features['y_min_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.min())
p10_features['z_min_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.min())
p10_features['x_min_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.min())
p10_features['y_min_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.min())
p10_features['z_min_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.min())



# FFT max
p10_features['x_max_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: x.max())
p10_features['y_max_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: x.max())
p10_features['z_max_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: x.max())
p10_features['x_max_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: x.max())
p10_features['y_max_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: x.max())
p10_features['z_max_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: x.max())
p10_features['x_max_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: x.max())
p10_features['y_max_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: x.max())
p10_features['z_max_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: x.max())


# FFT max-min diff
p10_features['x_maxmin_diff_fft_Acc'] =     p10_features['x_max_fft_Acc'] - p10_features['x_min_fft_Acc']
p10_features['y_maxmin_diff_fft_Acc'] =     p10_features['y_max_fft_Acc'] - p10_features['y_min_fft_Acc']
p10_features['z_maxmin_diff_fft_Acc'] =     p10_features['z_max_fft_Acc'] - p10_features['z_min_fft_Acc']
p10_features['x_maxmin_diff_fft_Lin'] =     p10_features['x_max_fft_Lin'] - p10_features['x_min_fft_Lin']
p10_features['y_maxmin_diff_fft_Lin'] =     p10_features['y_max_fft_Lin'] - p10_features['y_min_fft_Lin']
p10_features['z_maxmin_diff_fft_Lin'] =     p10_features['z_max_fft_Lin'] - p10_features['z_min_fft_Lin']
p10_features['x_maxmin_diff_fft_Gyro'] =     p10_features['x_max_fft_Gyro'] - p10_features['x_min_fft_Gyro']
p10_features['y_maxmin_diff_fft_Gyro'] =     p10_features['y_max_fft_Gyro'] - p10_features['y_min_fft_Gyro']
p10_features['z_maxmin_diff_fft_Gyro'] =     p10_features['z_max_fft_Gyro'] - p10_features['z_min_fft_Gyro']

# FFT median
p10_features['x_median_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(x))
p10_features['y_median_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(x))
p10_features['z_median_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(x))
p10_features['x_median_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(x))
p10_features['y_median_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(x))
p10_features['z_median_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(x))
p10_features['x_median_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(x))
p10_features['y_median_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(x))
p10_features['z_median_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(x))

# FFT median abs dev 
p10_features['x_mad_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['y_mad_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['z_mad_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['x_mad_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['y_mad_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['z_mad_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['x_mad_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['y_mad_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))
p10_features['z_mad_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.median(np.absolute(x - np.median(x))))


# FFT Interquartile range
p10_features['x_IQR_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['y_IQR_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['z_IQR_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['x_IQR_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['y_IQR_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['z_IQR_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['x_IQR_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['y_IQR_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
p10_features['z_IQR_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))



# FFT values above mean
p10_features['x_above_mean_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p10_features['y_above_mean_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p10_features['z_above_mean_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x > x.mean()))
p10_features['x_above_mean_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p10_features['y_above_mean_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p10_features['z_above_mean_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x > x.mean()))
p10_features['x_above_mean_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p10_features['y_above_mean_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))
p10_features['z_above_mean_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x > x.mean()))


# FFT number of peaks
p10_features['x_peak_count_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p10_features['y_peak_count_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p10_features['z_peak_count_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: len(find_peaks(x)[0]))
p10_features['x_peak_count_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p10_features['y_peak_count_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p10_features['z_peak_count_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: len(find_peaks(x)[0]))
p10_features['x_peak_count_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p10_features['y_peak_count_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))
p10_features['z_peak_count_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: len(find_peaks(x)[0]))


# FFT skewness
p10_features['x_skewness_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.skew(x))
p10_features['y_skewness_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.skew(x))
p10_features['z_skewness_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.skew(x))
p10_features['x_skewness_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.skew(x))
p10_features['y_skewness_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.skew(x))
p10_features['z_skewness_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.skew(x))
p10_features['x_skewness_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.skew(x))
p10_features['y_skewness_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.skew(x))
p10_features['z_skewness_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.skew(x))


# FFT kurtosis
p10_features['x_kurtosis_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p10_features['y_kurtosis_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p10_features['z_kurtosis_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: stats.kurtosis(x))
p10_features['x_kurtosis_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p10_features['y_kurtosis_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p10_features['z_kurtosis_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: stats.kurtosis(x))
p10_features['x_kurtosis_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p10_features['y_kurtosis_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))
p10_features['z_kurtosis_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: stats.kurtosis(x))



# FFT energy
p10_features['x_energy_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p10_features['y_energy_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(x**2)/30)
p10_features['z_energy_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(x**2/30))
p10_features['x_energy_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p10_features['y_energy_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(x**2)/30)
p10_features['z_energy_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(x**2/30))
p10_features['x_energy_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p10_features['y_energy_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(x**2)/30)
p10_features['z_energy_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(x**2/30))


# FFT avg resultant
p10_features['avg_result_Accl_fft_Acc'] = [i.mean() for i in ((pd.Series(x_list_fft_Acc)**2 + pd.Series(y_list_fft_Acc)**2 + pd.Series(z_list_fft_Acc)**2)**0.5)]
p10_features['avg_result_Accl_fft_Lin'] = [i.mean() for i in ((pd.Series(x_list_fft_Lin)**2 + pd.Series(y_list_fft_Lin)**2 + pd.Series(z_list_fft_Lin)**2)**0.5)]
p10_features['avg_result_Accl_fft_Gyro'] = [i.mean() for i in ((pd.Series(x_list_fft_Gyro)**2 + pd.Series(y_list_fft_Gyro)**2 + pd.Series(z_list_fft_Gyro)**2)**0.5)]

# FFT Signal magnitude area
p10_features['sma_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Acc).apply(lambda x: np.sum(abs(x)/30))
p10_features['sma_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Lin).apply(lambda x: np.sum(abs(x)/30))
p10_features['sma_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) + pd.Series(y_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30)) \
                 + pd.Series(z_list_fft_Gyro).apply(lambda x: np.sum(abs(x)/30))




# Max Indices and Min indices 

# index of max value in time domain
p10_features['x_argmax_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmax(x))
p10_features['y_argmax_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmax(x))
p10_features['z_argmax_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmax(x))
p10_features['x_argmax_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmax(x))
p10_features['y_argmax_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmax(x))
p10_features['z_argmax_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmax(x))
p10_features['x_argmax_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmax(x))
p10_features['y_argmax_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmax(x))
p10_features['z_argmax_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmax(x))


# index of min value in time domain
p10_features['x_argmin_Acc'] = pd.Series(x_list_Acc).apply(lambda x: np.argmin(x))
p10_features['y_argmin_Acc'] = pd.Series(y_list_Acc).apply(lambda x: np.argmin(x))
p10_features['z_argmin_Acc'] = pd.Series(z_list_Acc).apply(lambda x: np.argmin(x))
p10_features['x_argmin_Lin'] = pd.Series(x_list_Lin).apply(lambda x: np.argmin(x))
p10_features['y_argmin_Lin'] = pd.Series(y_list_Lin).apply(lambda x: np.argmin(x))
p10_features['z_argmin_Lin'] = pd.Series(z_list_Lin).apply(lambda x: np.argmin(x))
p10_features['x_argmin_Gyro'] = pd.Series(x_list_Gyro).apply(lambda x: np.argmin(x))
p10_features['y_argmin_Gyro'] = pd.Series(y_list_Gyro).apply(lambda x: np.argmin(x))
p10_features['z_argmin_Gyro'] = pd.Series(z_list_Gyro).apply(lambda x: np.argmin(x))


# absolute difference between above indices
p10_features['x_arg_diff_Acc'] = abs(    p10_features['x_argmax_Acc'] -     p10_features['x_argmin_Acc'])
p10_features['y_arg_diff_Acc'] = abs(    p10_features['y_argmax_Acc'] -     p10_features['y_argmin_Acc'])
p10_features['z_arg_diff_Acc'] = abs(    p10_features['z_argmax_Acc'] -     p10_features['z_argmin_Acc'])
p10_features['x_arg_diff_Lin'] = abs(    p10_features['x_argmax_Lin'] -     p10_features['x_argmin_Lin'])
p10_features['y_arg_diff_Lin'] = abs(    p10_features['y_argmax_Lin'] -     p10_features['y_argmin_Lin'])
p10_features['z_arg_diff_Lin'] = abs(    p10_features['z_argmax_Lin'] -     p10_features['z_argmin_Lin'])
p10_features['x_arg_diff_Gyro'] = abs(    p10_features['x_argmax_Gyro'] -     p10_features['x_argmin_Gyro'])
p10_features['y_arg_diff_Gyro'] = abs(    p10_features['y_argmax_Gyro'] -     p10_features['y_argmin_Gyro'])
p10_features['z_arg_diff_Gyro'] = abs(    p10_features['z_argmax_Gyro'] -     p10_features['z_argmin_Gyro'])


# index of max value in frequency domain
p10_features['x_argmax_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['y_argmax_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['z_argmax_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['x_argmax_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['y_argmax_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['z_argmax_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['x_argmax_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['y_argmax_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))
p10_features['z_argmax_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmax(np.abs(np.fft.fft(x))[1:31]))


# index of min value in frequency domain
p10_features['x_argmin_fft_Acc'] = pd.Series(x_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['y_argmin_fft_Acc'] = pd.Series(y_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['z_argmin_fft_Acc'] = pd.Series(z_list_fft_Acc).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['x_argmin_fft_Lin'] = pd.Series(x_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['y_argmin_fft_Lin'] = pd.Series(y_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['z_argmin_fft_Lin'] = pd.Series(z_list_fft_Lin).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['x_argmin_fft_Gyro'] = pd.Series(x_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['y_argmin_fft_Gyro'] = pd.Series(y_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))
p10_features['z_argmin_fft_Gyro'] = pd.Series(z_list_fft_Gyro).apply(lambda x: np.argmin(np.abs(np.fft.fft(x))[1:31]))


# absolute difference between above indices
p10_features['x_arg_diff_fft_Acc'] = abs(p10_features['x_argmax_fft_Acc'] - p10_features['x_argmin_fft_Acc'])
p10_features['y_arg_diff_fft_Acc'] = abs(p10_features['y_argmax_fft_Acc'] - p10_features['y_argmin_fft_Acc'])
p10_features['z_arg_diff_fft_Acc'] = abs(p10_features['z_argmax_fft_Acc'] - p10_features['z_argmin_fft_Acc'])
p10_features['x_arg_diff_fft_Lin'] = abs(p10_features['x_argmax_fft_Lin'] - p10_features['x_argmin_fft_Lin'])
p10_features['y_arg_diff_fft_Lin'] = abs(p10_features['y_argmax_fft_Lin'] - p10_features['y_argmin_fft_Lin'])
p10_features['z_arg_diff_fft_Lin'] = abs(p10_features['z_argmax_fft_Lin'] - p10_features['z_argmin_fft_Lin'])
p10_features['x_arg_diff_fft_Gyro'] = abs(p10_features['x_argmax_fft_Gyro'] - p10_features['x_argmin_fft_Gyro'])
p10_features['y_arg_diff_fft_Gyro'] = abs(p10_features['y_argmax_fft_Gyro'] - p10_features['y_argmin_fft_Gyro'])
p10_features['z_arg_diff_fft_Gyro'] = abs(p10_features['z_argmax_fft_Gyro'] - p10_features['z_argmin_fft_Gyro'])

p10_features['label_of_activity']=p10_labels

# storing the obtained dataframe to csv
p10_features.to_csv('p10_features.csv',index_label='ID')
