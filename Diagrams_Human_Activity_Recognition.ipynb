# %%
# Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# load data for participant-1
p1_raw = pd.read_csv("C:/Users/USER/Downloads/Data Mining Project/Data Mining Project/Useful_Data/Data_5/DataSet/Participant_1.csv",header=1)

# %%
p1_raw.rename(columns={'Unnamed: 69':'label'},inplace=True)
p1_raw.drop(['time_stamp','Mx', 'My', 'Mz','Unnamed: 13', 'time_stamp.1','Mx.1', 'My.1', 'Mz.1',
       'Unnamed: 27', 'time_stamp.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
       'time_stamp.3','Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4','Mx.4', 'My.4', 'Mz.4'], axis=1, inplace=True)
p1_raw.rename(columns={'Ax':'Ax_LP', 'Ay':'Ay_LP', 'Az':'Az_LP', 'Lx':'Lx_LP', 'Ly':'Ly_LP', 'Lz':'Lz_LP', 'Gx':'Gx_LP', 'Gy':'Gy_LP', 'Gz':'Gz_LP','Ax.1':'Ax_RP', 'Ay.1':'Ay_RP', 'Az.1':'Az_RP', 'Lx.1':'Lx_RP', 'Ly.1':'Ly_RP', 'Lz.1':'Lz_RP', 'Gx.1':'Gx_RP', 'Gy.1':'Gy_RP', 'Gz.1':'Gz_RP','Ax.2':'Ax_Wr', 'Ay.2':'Ay_Wr', 'Az.2':'Az_Wr', 'Lx.2':'Lx_Wr', 'Ly.2':'Ly_Wr', 'Lz.2':'Lz_Wr', 'Gx.2':'Gx_Wr', 'Gy.2':'Gy_Wr', 'Gz.2':'Gz_Wr','Ax.3':'Ax_UA', 'Ay.3':'Ay_UA', 'Az.3':'Az_UA', 'Lx.3':'Lx_UA', 'Ly.3':'Ly_UA', 'Lz.3':'Lz_UA', 'Gx.3':'Gx_UA', 'Gy.3':'Gy_UA', 'Gz.3':'Gz_UA','Ax.4':'Ax_Blt', 'Ay.4':'Ay_Blt', 'Az.4':'Az_Blt', 'Lx.4':'Lx_Blt', 'Ly.4':'Ly_Blt', 'Lz.4':'Lz_Blt', 'Gx.4':'Gx_Blt', 'Gy.4':'Gy_Blt', 'Gz.4':'Gz_Blt'}, inplace=True)

# %%
p1_raw
# Out:
#           Ax_LP    Ay_LP     Az_LP    Lx_LP   Ly_LP     Lz_LP    Gx_LP  \
# 0     -1.811500 -14.8730 -1.348400 -1.26910 -5.1057 -0.664450 -0.53206
# 1      0.245170 -14.0700 -0.844460  0.70147 -4.2969 -0.171990 -0.25229
# 2     -0.572050 -14.6280 -1.757000 -0.21760 -4.8531 -1.056500 -1.04920
# 3     -0.694640 -12.9390 -3.091800 -0.32273 -3.1786 -2.219700 -2.37200
# 4      0.871700 -12.0000 -1.566300  1.13740 -2.2390 -0.654760 -2.79010
# ...         ...      ...       ...      ...     ...       ...      ...
# 62995  0.054481  -7.8589 -2.982900 -1.57750  1.7975 -3.492600 -0.27550
# 62996  0.844460  -7.5593 -2.329100 -0.79722  2.1015 -2.708100 -0.39248
# 62997  0.354130  -6.5786 -0.095342 -1.29470  3.0850 -0.350820 -0.22205
# 62998  0.122580  -6.4833  0.245170 -1.52370  3.1816  0.021841 -0.24129
# 62999 -0.640160  -7.1643 -1.103200 -2.45230  2.5070 -1.189900 -0.38179
#
#          Gy_LP     Gz_LP    Ax_RP  ...   Ax_Blt   Ay_Blt   Az_Blt  Lx_Blt  \
# ...

# %%
# load feature data for participant-1
p1_mean = pd.read_csv("p1.csv")
p1_mean.drop(['ID'],axis=1,inplace=True)

# %%
p1_mean
# Out:
#           Acc_x      Acc_y     Acc_z     Lin_x     Lin_y     Lin_z    Gyro_x  \
# 0      0.855372 -10.847180 -0.098070 -3.200022 -3.656998  0.205127 -0.795471
# 1      1.105982 -11.206980 -0.217924 -2.859594 -3.959698 -0.002575 -0.729746
# 2      0.509400 -11.013320 -0.656480 -3.274600 -3.706642 -0.524974 -0.906652
# 3      0.237008 -10.373060 -1.010640 -3.381526 -3.006652 -0.897800 -1.175130
# 4      1.743404  -9.139392 -1.283020 -1.771792 -1.706571 -1.144098 -1.261498
# ...         ...        ...       ...       ...       ...       ...       ...
# 62995  3.138176  -6.807440 -1.631734  0.369576  0.906280 -0.119846  0.566822
# 62996  3.810932  -6.325220 -1.639880  1.028937  1.400140 -0.206552  0.553618
# 62997  4.086146  -6.406940 -1.492780  1.292983  1.335380 -0.145462  0.711656
# 62998  4.015336  -7.014520 -1.727058  1.251961  0.773800 -0.487812  0.661499
# 62999  3.688460  -7.673760 -1.661686  0.948780  0.168040 -0.524960  0.592608
#
#          Gyro_y    Gyro_z label_of_activity
# ...

# %%
# Accelerometer(x)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(1,2,1)
plt.plot(p1_raw.loc[0:150,['Ax_LP','Ax_RP','Ax_Wr','Ax_UA','Ax_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(1,2,2)
plt.plot(p1_mean.loc[0:150,['Acc_x']])

# %%
# Accelerometer(y)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(1,2,1)
plt.plot(p1_raw.loc[0:150,['Ay_LP','Ay_RP','Ay_Wr','Ay_UA','Ay_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(1,2,2)
plt.plot(p1_mean.loc[0:150,['Acc_y']])

# %%
# Accelerometer(z)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(1,2,1)
plt.plot(p1_raw.loc[0:150,['Az_LP','Az_RP','Az_Wr','Az_UA','Az_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(1,2,2)
plt.plot(p1_mean.loc[0:150,['Acc_z']])

# %%
# Linscope(x)
plt.figure(figsize=(15,10))
# combined diagram for 5 different sensors
plt.subplot(3,2,1)
plt.plot(p1_raw.loc[0:150,['Lx_LP','Lx_RP','Lx_Wr','Lx_UA','Lx_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(3,2,2)
plt.plot(p1_mean.loc[0:150,['Lin_x']])

# Linscope(y)
plt.figure(figsize=(15,10))
# combined diagram for 5 different sensors
plt.subplot(3,2,3)
plt.plot(p1_raw.loc[0:150,['Ly_LP','Ly_RP','Ly_Wr','Ly_UA','Ly_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(3,2,4)
plt.plot(p1_mean.loc[0:150,['Lin_y']])

# Linscope(z)
plt.figure(figsize=(15,10))
# combined diagram for 5 different sensors
plt.subplot(3,2,5)
plt.plot(p1_raw.loc[0:150,['Lz_LP','Lz_RP','Lz_Wr','Lz_UA','Lz_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(3,2,6)
plt.plot(p1_mean.loc[0:150,['Lin_z']])

# %%
# Gyroscope(x)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(3,2,1)
plt.plot(p1_raw.loc[0:150,['Gx_LP','Gx_RP','Gx_Wr','Gx_UA','Gx_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(3,2,2)
plt.plot(p1_mean.loc[0:150,['Gyro_x']])

# Gyroscope(y)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(3,2,3)
plt.plot(p1_raw.loc[0:150,['Gy_LP','Gy_RP','Gy_Wr','Gy_UA','Gy_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(3,2,4)
plt.plot(p1_mean.loc[0:150,['Gyro_y']])

# Gyroscope(z)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(3,2,5)
plt.plot(p1_raw.loc[0:150,['Gz_LP','Gz_RP','Gz_Wr','Gz_UA','Gz_Blt']])
plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(3,2,6)
plt.plot(p1_mean.loc[0:150,['Gyro_z']])

# %%
# time domain signal 
plt.plot(x_list_Acc[0])

# %%
# transformed frequency domain signals
plt.plot(x_list_fft_Acc[0])

# %%
# Gyroscope(x)
plt.figure(figsize=(15,5))
# combined diagram for 5 different sensors
plt.subplot(1,2,1)
plt.plot(x_list_Acc[0])
#plt.legend(['Left Pocket','Right Pocket','Wrist','Upper Arm','Belt'])
# data taking mean of 5 different sensors (our used data in the project)
plt.subplot(1,2,2)
plt.plot(x_list_fft_Acc[0])

# %%
# load feature data for participant-1
d1 = pd.read_csv("p1_features.csv")
d1.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-2
d2 = pd.read_csv("p2_features.csv")
d2.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-3
d3 = pd.read_csv("p3_features.csv")
d3.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-4
d4 = pd.read_csv("p4_features.csv")
d4.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-5
d5 = pd.read_csv("p5_features.csv")
d5.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-6
d6 = pd.read_csv("p6_features.csv")
d6.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-7
d7 = pd.read_csv("p7_features.csv")
d7.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-8
d8 = pd.read_csv("p8_features.csv")
d8.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-9
d9 = pd.read_csv("p9_features.csv")
d9.drop(['ID'],axis=1,inplace=True)
# load feature data for participant-10
d10 = pd.read_csv("p10_features.csv")
d10.drop(['ID'],axis=1,inplace=True)

# %%
d1.head()
# Out:
#    x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0    3.030197   -8.305953    0.092324    0.117246   -0.571045    0.177267
# 1    3.021265   -8.341569    0.168419   -0.091852   -0.639241    0.194135
# 2    3.113552   -8.211453    0.150912    0.193602   -0.474490    0.192857
# 3    2.935254   -8.307903    0.041207   -0.094728   -0.613727    0.056220
# 4    2.968238   -8.303224    0.073024   -0.006570   -0.613585    0.123650
#
#    x_mean_Gyro  y_mean_Gyro  z_mean_Gyro  x_std_Acc  ...  x_arg_diff_fft_Acc  \
# 0    -0.069521     0.005934     0.040006   1.362155  ...                   7
# 1    -0.041765    -0.056080    -0.011651   1.406318  ...                  14
# 2    -0.008717    -0.000823    -0.018593   1.339181  ...                  25
# 3    -0.090329    -0.009500     0.026123   1.388293  ...                   5
# 4     0.028699     0.017324    -0.044260   1.297101  ...                  12
#
# ...

# %%
d1['label_of_activity'].unique()
# Out:
# array(['walking', 'standing', 'jogging', 'sitting', 'biking', 'upstairs',
#        'downstairs'], dtype=object)

# %% [markdown]
# ## Walking

# %%
p1_walking = d1[d1['label_of_activity']=='walking']['x_mean_Acc']
p2_walking = d2[d2['label_of_activity']=='walking']['x_mean_Acc']
p3_walking = d3[d3['label_of_activity']=='walking']['x_mean_Acc']
p4_walking = d4[d4['label_of_activity']=='walking']['x_mean_Acc']
p5_walking = d5[d5['label_of_activity']=='walking']['x_mean_Acc']
p6_walking = d6[d6['label_of_activity']=='walking']['x_mean_Acc']
p7_walking = d7[d7['label_of_activity']=='walking']['x_mean_Acc']
p8_walking = d8[d8['label_of_activity']=='walking']['x_mean_Acc']
p9_walking = d9[d9['label_of_activity']=='walking']['x_mean_Acc']
p10_walking = d10[d10['label_of_activity']=='walking']['x_mean_Acc']

# %%
p1_walking
# Out:
# 0      3.030197
# 1      3.021265
# 2      3.113552
# 3      2.935254
# 4      2.968238
#          ...
# 293    2.809666
# 294    2.905989
# 295    2.805030
# 296    2.858784
# 297    2.789736
# Name: x_mean_Acc, Length: 298, dtype: float64

# %%
# plot x_mean_Acc for walking for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_walking)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_walking)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_walking)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_walking)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_walking)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_walking)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_walking)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_walking)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_walking)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_walking)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')

# %% [markdown]
# ## Standing

# %%
p1_standing = d1[d1['label_of_activity']=='standing']['x_mean_Acc']
p2_standing = d2[d2['label_of_activity']=='standing']['x_mean_Acc']
p3_standing = d3[d3['label_of_activity']=='standing']['x_mean_Acc']
p4_standing = d4[d4['label_of_activity']=='standing']['x_mean_Acc']
p5_standing = d5[d5['label_of_activity']=='standing']['x_mean_Acc']
p6_standing = d6[d6['label_of_activity']=='standing']['x_mean_Acc']
p7_standing = d7[d7['label_of_activity']=='standing']['x_mean_Acc']
p8_standing = d8[d8['label_of_activity']=='standing']['x_mean_Acc']
p9_standing = d9[d9['label_of_activity']=='standing']['x_mean_Acc']
p10_standing = d10[d10['label_of_activity']=='standing']['x_mean_Acc']

# %%
# plot x_mean_Acc for standing for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_standing)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_standing)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_standing)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_standing)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_standing)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_standing)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_standing)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_standing)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_standing)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_standing)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')

# %% [markdown]
# ## Jogging

# %%
p1_jogging = d1[d1['label_of_activity']=='jogging']['x_mean_Acc']
p2_jogging = d2[d2['label_of_activity']=='jogging']['x_mean_Acc']
p3_jogging = d3[d3['label_of_activity']=='jogging']['x_mean_Acc']
p4_jogging = d4[d4['label_of_activity']=='jogging']['x_mean_Acc']
p5_jogging = d5[d5['label_of_activity']=='jogging']['x_mean_Acc']
p6_jogging = d6[d6['label_of_activity']=='jogging']['x_mean_Acc']
p7_jogging = d7[d7['label_of_activity']=='jogging']['x_mean_Acc']
p8_jogging = d8[d8['label_of_activity']=='jogging']['x_mean_Acc']
p9_jogging = d9[d9['label_of_activity']=='jogging']['x_mean_Acc']
p10_jogging = d10[d10['label_of_activity']=='jogging']['x_mean_Acc']

# %%
# plot x_mean_Acc for jogging for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_jogging)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_jogging)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_jogging)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_jogging)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_jogging)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_jogging)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_jogging)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_jogging)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_jogging)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_jogging)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')

# %% [markdown]
# ## Sitting

# %%
p1_sitting = d1[d1['label_of_activity']=='sitting']['x_mean_Acc']
p2_sitting = d2[d2['label_of_activity']=='sitting']['x_mean_Acc']
p3_sitting = d3[d3['label_of_activity']=='sitting']['x_mean_Acc']
p4_sitting = d4[d4['label_of_activity']=='sitting']['x_mean_Acc']
p5_sitting = d5[d5['label_of_activity']=='sitting']['x_mean_Acc']
p6_sitting = d6[d6['label_of_activity']=='sitting']['x_mean_Acc']
p7_sitting = d7[d7['label_of_activity']=='sitting']['x_mean_Acc']
p8_sitting = d8[d8['label_of_activity']=='sitting']['x_mean_Acc']
p9_sitting = d9[d9['label_of_activity']=='sitting']['x_mean_Acc']
p10_sitting = d10[d10['label_of_activity']=='sitting']['x_mean_Acc']

# %%
# plot x_mean_Acc for sitting for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_sitting)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_sitting)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_sitting)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_sitting)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_sitting)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_sitting)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_sitting)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_sitting)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_sitting)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_sitting)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')

# %% [markdown]
# ## Biking

# %%
p1_biking = d1[d1['label_of_activity']=='biking']['x_mean_Acc']
p2_biking = d2[d2['label_of_activity']=='biking']['x_mean_Acc']
p3_biking = d3[d3['label_of_activity']=='biking']['x_mean_Acc']
p4_biking = d4[d4['label_of_activity']=='biking']['x_mean_Acc']
p5_biking = d5[d5['label_of_activity']=='biking']['x_mean_Acc']
p6_biking = d6[d6['label_of_activity']=='biking']['x_mean_Acc']
p7_biking = d7[d7['label_of_activity']=='biking']['x_mean_Acc']
p8_biking = d8[d8['label_of_activity']=='biking']['x_mean_Acc']
p9_biking = d9[d9['label_of_activity']=='biking']['x_mean_Acc']
p10_biking = d10[d10['label_of_activity']=='biking']['x_mean_Acc']

# %%
# plot x_mean_Acc for biking for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_biking)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_biking)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_biking)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_biking)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_biking)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_biking)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_biking)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_biking)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_biking)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_biking)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')

# %% [markdown]
# ##  Upstairs

# %%
p1_upstairs = d1[d1['label_of_activity']=='upstairs']['x_mean_Acc']
p2_upstairs = d2[d2['label_of_activity']=='upstairs']['x_mean_Acc']
p3_upstairs = d3[d3['label_of_activity']=='upstairs']['x_mean_Acc']
p4_upstairs = d4[d4['label_of_activity']=='upstairs']['x_mean_Acc']
p5_upstairs = d5[d5['label_of_activity']=='upstairs']['x_mean_Acc']
p6_upstairs = d6[d6['label_of_activity']=='upstairs']['x_mean_Acc']
p7_upstairs = d7[d7['label_of_activity']=='upstairs']['x_mean_Acc']
p8_upstairs = d8[d8['label_of_activity']=='upstairs']['x_mean_Acc']
p9_upstairs = d9[d9['label_of_activity']=='upstairs']['x_mean_Acc']
p10_upstairs = d10[d10['label_of_activity']=='upstairs']['x_mean_Acc']

# %%
# plot x_mean_Acc for upstairs for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_upstairs)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_upstairs)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_upstairs)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_upstairs)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_upstairs)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_upstairs)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_upstairs)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_upstairs)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_upstairs)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_upstairs)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')

# %% [markdown]
# ## Downstairs

# %%
p1_downstairs = d1[d1['label_of_activity']=='downstairs']['x_mean_Acc']
p2_downstairs = d2[d2['label_of_activity']=='downstairs']['x_mean_Acc']
p3_downstairs = d3[d3['label_of_activity']=='downstairs']['x_mean_Acc']
p4_downstairs = d4[d4['label_of_activity']=='downstairs']['x_mean_Acc']
p5_downstairs = d5[d5['label_of_activity']=='downstairs']['x_mean_Acc']
p6_downstairs = d6[d6['label_of_activity']=='downstairs']['x_mean_Acc']
p7_downstairs = d7[d7['label_of_activity']=='downstairs']['x_mean_Acc']
p8_downstairs = d8[d8['label_of_activity']=='downstairs']['x_mean_Acc']
p9_downstairs = d9[d9['label_of_activity']=='downstairs']['x_mean_Acc']
p10_downstairs = d10[d10['label_of_activity']=='downstairs']['x_mean_Acc']

# %%
# plot x_mean_Acc for downstairs for each participant
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p1_downstairs)
plt.xlabel('Participant-1')

plt.subplot(1,3,2)
plt.plot(p2_downstairs)
plt.xlabel('Participant-2')

plt.subplot(1,3,3)
plt.plot(p3_downstairs)
plt.xlabel('Participant-3')
# Out:
# Text(0.5, 0, 'Participant-3')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p4_downstairs)
plt.xlabel('Participant-4')

plt.subplot(1,3,2)
plt.plot(p5_downstairs)
plt.xlabel('Participant-5')

plt.subplot(1,3,3)
plt.plot(p6_downstairs)
plt.xlabel('Participant-6')
# Out:
# Text(0.5, 0, 'Participant-6')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(p7_downstairs)
plt.xlabel('Participant-7')

plt.subplot(1,3,2)
plt.plot(p8_downstairs)
plt.xlabel('Participant-8')


plt.subplot(1,3,3)
plt.plot(p9_downstairs)
plt.xlabel('Participant-9')
# Out:
# Text(0.5, 0, 'Participant-9')

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,3,2)
plt.plot(p10_downstairs)
plt.xlabel('Participant-10')
# Out:
# Text(0.5, 0, 'Participant-10')
