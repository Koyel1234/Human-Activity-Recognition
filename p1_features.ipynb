# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv('p1_features.csv')

# %%
d1.head()
# Out:
#    ID  x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0   0    3.030197   -8.305953    0.092324    0.117246   -0.571045    0.177267
# 1   1    3.021265   -8.341569    0.168419   -0.091852   -0.639241    0.194135
# 2   2    3.113552   -8.211453    0.150912    0.193602   -0.474490    0.192857
# 3   3    2.935254   -8.307903    0.041207   -0.094728   -0.613727    0.056220
# 4   4    2.968238   -8.303224    0.073024   -0.006570   -0.613585    0.123650
#
#    x_mean_Gyro  y_mean_Gyro  z_mean_Gyro  ...  x_arg_diff_fft_Acc  \
# 0    -0.069521     0.005934     0.040006  ...                   7
# 1    -0.041765    -0.056080    -0.011651  ...                  14
# 2    -0.008717    -0.000823    -0.018593  ...                  25
# 3    -0.090329    -0.009500     0.026123  ...                   5
# 4     0.028699     0.017324    -0.044260  ...                  12
#
#    y_arg_diff_fft_Acc  z_arg_diff_fft_Acc  x_arg_diff_fft_Lin  \
# 0                   6                  14                  13
# 1                  14                  14                  20
# 2                   7                   3                   7
# 3                  10                  14                   8
# 4                   7                   6                   8
#
#    y_arg_diff_fft_Lin  z_arg_diff_fft_Lin  x_arg_diff_fft_Gyro  \
# 0                   8                   4                   15
# 1                  13                   4                   20
# 2                  14                   3                   12
# 3                   8                   3                    9
# 4                  20                  15                   20
#
#    y_arg_diff_fft_Gyro  z_arg_diff_fft_Gyro  label_of_activity
# 0                    4                   14            walking
# 1                    4                   20            walking
# 2                    9                   14            walking
# 3                    2                   14            walking
# 4                    6                   14            walking
#
# [5 rows x 338 columns]

# %%
for i in d1.columns:
    print(i)
# Out:
# ID
# x_mean_Acc
# y_mean_Acc
# z_mean_Acc
# x_mean_Lin
# y_mean_Lin
# z_mean_Lin
# x_mean_Gyro
# y_mean_Gyro
# z_mean_Gyro
# x_std_Acc
# y_std_Acc
# z_std_Acc
# x_std_Lin
# y_std_Lin
# z_std_Lin
# x_std_Gyro
# y_std_Gyro
# z_std_Gyro
# x_aad_Acc
# y_aad_Acc
# z_aad_Acc
# x_aad_Lin
# y_aad_Lin
# z_aad_Lin
# x_aad_Gyro
# y_aad_Gyro
# z_aad_Gyro
# x_min_Acc
# y_min_Acc
# z_min_Acc
# x_min_Lin
# y_min_Lin
# z_min_Lin
# x_min_Gyro
# y_min_Gyro
# z_min_Gyro
# x_max_Acc
# y_max_Acc
# z_max_Acc
# x_max_Lin
# y_max_Lin
# z_max_Lin
# x_max_Gyro
# y_max_Gyro
# z_max_Gyro
# x_maxmin_diff_Acc
# y_maxmin_diff_Acc
# z_maxmin_diff_Acc
# x_maxmin_diff_Lin
# y_maxmin_diff_Lin
# z_maxmin_diff_Lin
# x_maxmin_diff_Gyro
# y_maxmin_diff_Gyro
# z_maxmin_diff_Gyro
# x_median_Acc
# y_median_Acc
# z_median_Acc
# x_median_Lin
# y_median_Lin
# z_median_Lin
# x_median_Gyro
# y_median_Gyro
# z_median_Gyro
# x_mad_Acc
# y_mad_Acc
# z_mad_Acc
# x_mad_Lin
# y_mad_Lin
# z_mad_Lin
# x_mad_Gyro
# y_mad_Gyro
# z_mad_Gyro
# x_IQR_Acc
# y_IQR_Acc
# z_IQR_Acc
# x_IQR_Lin
# y_IQR_Lin
# z_IQR_Lin
# x_IQR_Gyro
# y_IQR_Gyro
# z_IQR_Gyro
# x_neg_count_Acc
# y_neg_count_Acc
# z_neg_count_Acc
# x_neg_count_Lin
# y_neg_count_Lin
# z_neg_count_Lin
# x_neg_count_Gyro
# y_neg_count_Gyro
# z_neg_count_Gyro
# x_pos_count_Acc
# y_pos_count_Acc
# z_pos_count_Acc
# x_pos_count_Lin
# y_pos_count_Lin
# z_pos_count_Lin
# x_pos_count_Gyro
# y_pos_count_Gyro
# z_pos_count_Gyro
# x_above_mean_Acc
# y_above_mean_Acc
# z_above_mean_Acc
# x_above_mean_Lin
# y_above_mean_Lin
# z_above_mean_Lin
# x_above_mean_Gyro
# y_above_mean_Gyro
# z_above_mean_Gyro
# x_peak_count_Acc
# y_peak_count_Acc
# z_peak_count_Acc
# x_peak_count_Lin
# y_peak_count_Lin
# z_peak_count_Lin
# x_peak_count_Gyro
# y_peak_count_Gyro
# z_peak_count_Gyro
# x_skewness_Acc
# y_skewness_Acc
# z_skewness_Acc
# x_skewness_Lin
# y_skewness_Lin
# z_skewness_Lin
# x_skewness_Gyro
# y_skewness_Gyro
# z_skewness_Gyro
# x_kurtosis_Acc
# y_kurtosis_Acc
# z_kurtosis_Acc
# x_kurtosis_Lin
# y_kurtosis_Lin
# z_kurtosis_Lin
# x_kurtosis_Gyro
# y_kurtosis_Gyro
# z_kurtosis_Gyro
# x_energy_Acc
# y_energy_Acc
# z_energy_Acc
# x_energy_Lin
# y_energy_Lin
# z_energy_Lin
# x_energy_Gyro
# y_energy_Gyro
# z_energy_Gyro
# avg_result_Acc
# avg_result_Lin
# avg_result_Gyro
# sma_Acc
# sma_Lin
# sma_Gyro
# x_mean_fft_Acc
# y_mean_fft_Acc
# z_mean_fft_Acc
# x_mean_fft_Lin
# y_mean_fft_Lin
# z_mean_fft_Lin
# x_mean_fft_Gyro
# y_mean_fft_Gyro
# z_mean_fft_Gyro
# x_std_fft_Acc
# y_std_fft_Acc
# z_std_fft_Acc
# x_std_fft_Lin
# y_std_fft_Lin
# z_std_fft_Lin
# x_std_fft_Gyro
# y_std_fft_Gyro
# z_std_fft_Gyro
# x_aad_fft_Acc
# y_aad_fft_Acc
# z_aad_fft_Acc
# x_aad_fft_Lin
# y_aad_fft_Lin
# z_aad_fft_Lin
# x_aad_fft_Gyro
# y_aad_fft_Gyro
# z_aad_fft_Gyro
# x_min_fft_Acc
# y_min_fft_Acc
# z_min_fft_Acc
# x_min_fft_Lin
# y_min_fft_Lin
# z_min_fft_Lin
# x_min_fft_Gyro
# y_min_fft_Gyro
# z_min_fft_Gyro
# x_max_fft_Acc
# y_max_fft_Acc
# z_max_fft_Acc
# x_max_fft_Lin
# y_max_fft_Lin
# z_max_fft_Lin
# x_max_fft_Gyro
# y_max_fft_Gyro
# z_max_fft_Gyro
# x_maxmin_diff_fft_Acc
# y_maxmin_diff_fft_Acc
# z_maxmin_diff_fft_Acc
# x_maxmin_diff_fft_Lin
# y_maxmin_diff_fft_Lin
# z_maxmin_diff_fft_Lin
# x_maxmin_diff_fft_Gyro
# y_maxmin_diff_fft_Gyro
# z_maxmin_diff_fft_Gyro
# x_median_fft_Acc
# y_median_fft_Acc
# z_median_fft_Acc
# x_median_fft_Lin
# y_median_fft_Lin
# z_median_fft_Lin
# x_median_fft_Gyro
# y_median_fft_Gyro
# z_median_fft_Gyro
# x_mad_fft_Acc
# y_mad_fft_Acc
# z_mad_fft_Acc
# x_mad_fft_Lin
# y_mad_fft_Lin
# z_mad_fft_Lin
# x_mad_fft_Gyro
# y_mad_fft_Gyro
# z_mad_fft_Gyro
# x_IQR_fft_Acc
# y_IQR_fft_Acc
# z_IQR_fft_Acc
# x_IQR_fft_Lin
# y_IQR_fft_Lin
# z_IQR_fft_Lin
# x_IQR_fft_Gyro
# y_IQR_fft_Gyro
# z_IQR_fft_Gyro
# x_above_mean_fft_Acc
# y_above_mean_fft_Acc
# z_above_mean_fft_Acc
# x_above_mean_fft_Lin
# y_above_mean_fft_Lin
# z_above_mean_fft_Lin
# x_above_mean_fft_Gyro
# y_above_mean_fft_Gyro
# z_above_mean_fft_Gyro
# x_peak_count_fft_Acc
# y_peak_count_fft_Acc
# z_peak_count_fft_Acc
# x_peak_count_fft_Lin
# y_peak_count_fft_Lin
# z_peak_count_fft_Lin
# x_peak_count_fft_Gyro
# y_peak_count_fft_Gyro
# z_peak_count_fft_Gyro
# x_skewness_fft_Acc
# y_skewness_fft_Acc
# z_skewness_fft_Acc
# x_skewness_fft_Lin
# y_skewness_fft_Lin
# z_skewness_fft_Lin
# x_skewness_fft_Gyro
# y_skewness_fft_Gyro
# z_skewness_fft_Gyro
# x_kurtosis_fft_Acc
# y_kurtosis_fft_Acc
# z_kurtosis_fft_Acc
# x_kurtosis_fft_Lin
# y_kurtosis_fft_Lin
# z_kurtosis_fft_Lin
# x_kurtosis_fft_Gyro
# y_kurtosis_fft_Gyro
# z_kurtosis_fft_Gyro
# x_energy_fft_Acc
# y_energy_fft_Acc
# z_energy_fft_Acc
# x_energy_fft_Lin
# y_energy_fft_Lin
# z_energy_fft_Lin
# x_energy_fft_Gyro
# y_energy_fft_Gyro
# z_energy_fft_Gyro
# avg_result_Accl_fft_Acc
# avg_result_Accl_fft_Lin
# avg_result_Accl_fft_Gyro
# sma_fft_Acc
# sma_fft_Lin
# sma_fft_Gyro
# x_argmax_Acc
# y_argmax_Acc
# z_argmax_Acc
# x_argmax_Lin
# y_argmax_Lin
# z_argmax_Lin
# x_argmax_Gyro
# y_argmax_Gyro
# z_argmax_Gyro
# x_argmin_Acc
# y_argmin_Acc
# z_argmin_Acc
# x_argmin_Lin
# y_argmin_Lin
# z_argmin_Lin
# x_argmin_Gyro
# y_argmin_Gyro
# z_argmin_Gyro
# x_arg_diff_Acc
# y_arg_diff_Acc
# z_arg_diff_Acc
# x_arg_diff_Lin
# y_arg_diff_Lin
# z_arg_diff_Lin
# x_arg_diff_Gyro
# y_arg_diff_Gyro
# z_arg_diff_Gyro
# x_argmax_fft_Acc
# y_argmax_fft_Acc
# z_argmax_fft_Acc
# x_argmax_fft_Lin
# y_argmax_fft_Lin
# z_argmax_fft_Lin
# x_argmax_fft_Gyro
# y_argmax_fft_Gyro
# z_argmax_fft_Gyro
# x_argmin_fft_Acc
# y_argmin_fft_Acc
# z_argmin_fft_Acc
# x_argmin_fft_Lin
# y_argmin_fft_Lin
# z_argmin_fft_Lin
# x_argmin_fft_Gyro
# y_argmin_fft_Gyro
# z_argmin_fft_Gyro
# x_arg_diff_fft_Acc
# y_arg_diff_fft_Acc
# z_arg_diff_fft_Acc
# x_arg_diff_fft_Lin
# y_arg_diff_fft_Lin
# z_arg_diff_fft_Lin
# x_arg_diff_fft_Gyro
# y_arg_diff_fft_Gyro
# z_arg_diff_fft_Gyro
# label_of_activity

# %%
d1.shape
# Out:
# (2095, 338)

# %%
d1.drop(["ID"],axis=1,inplace=True)

# %%
d1['label_of_activity'].unique()
# Out:
# array(['walking', 'standing', 'jogging', 'sitting', 'biking', 'upstairs',
#        'downstairs'], dtype=object)

# %%
d1.replace('walking',0,inplace=True)
d1.replace('standing',1,inplace=True)
d1.replace('jogging',2,inplace=True)
d1.replace('sitting',3,inplace=True)
d1.replace('biking',4,inplace=True)
d1.replace('upstairs',5,inplace=True)
d1.replace('downstairs',6,inplace=True)

# %%
d1.head()
# Out:
#    x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 0    3.030197   -8.305953    0.092324    0.117246   -0.571045    0.177267
# 1    3.021265   -8.341569    0.168419   -0.091852   -0.639241    0.194135
# 2    3.113552   -8.211453    0.150912    0.193602   -0.474490    0.192857
# 3    2.935254   -8.307903    0.041207   -0.094728   -0.613727    0.056220
# 4    2.968238   -8.303224    0.073024   -0.006570   -0.613585    0.123650
#
#    x_mean_Gyro  y_mean_Gyro  z_mean_Gyro  x_std_Acc  ...  x_arg_diff_fft_Acc  \
# 0    -0.069521     0.005934     0.040006   1.362155  ...                   7
# 1    -0.041765    -0.056080    -0.011651   1.406318  ...                  14
# 2    -0.008717    -0.000823    -0.018593   1.339181  ...                  25
# 3    -0.090329    -0.009500     0.026123   1.388293  ...                   5
# 4     0.028699     0.017324    -0.044260   1.297101  ...                  12
#
#    y_arg_diff_fft_Acc  z_arg_diff_fft_Acc  x_arg_diff_fft_Lin  \
# 0                   6                  14                  13
# 1                  14                  14                  20
# 2                   7                   3                   7
# 3                  10                  14                   8
# 4                   7                   6                   8
#
#    y_arg_diff_fft_Lin  z_arg_diff_fft_Lin  x_arg_diff_fft_Gyro  \
# 0                   8                   4                   15
# 1                  13                   4                   20
# 2                  14                   3                   12
# 3                   8                   3                    9
# 4                  20                  15                   20
#
#    y_arg_diff_fft_Gyro  z_arg_diff_fft_Gyro  label_of_activity
# 0                    4                   14                  0
# 1                    4                   20                  0
# 2                    9                   14                  0
# 3                    2                   14                  0
# 4                    6                   14                  0
#
# [5 rows x 337 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = d1.iloc[:,0:335]
y = d1['label_of_activity']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train , y_test = train_test_split(X,y,test_size=0.3)

# %%
scaler = MinMaxScaler()
X_train[list(X_train.columns)] = scaler.fit_transform(X_train[list(X_train.columns)])
X_test[list(X_test.columns)] = scaler.transform(X_test[list(X_test.columns)])
# Out:
# <ipython-input-13-3d0b614e0c44>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[list(X_train.columns)] = scaler.fit_transform(X_train[list(X_train.columns)])
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# <ipython-input-13-3d0b614e0c44>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[list(X_test.columns)] = scaler.transform(X_test[list(X_test.columns)])
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
X_train=pd.DataFrame(X_train)
X_test=pd.DataFrame(X_test)

# %%
X_train.head()
# Out:
#       x_mean_Acc  y_mean_Acc  z_mean_Acc  x_mean_Lin  y_mean_Lin  z_mean_Lin  \
# 1642    0.228507    0.033852    0.743859    0.557067    0.230108    0.677006
# 2010    0.284665    0.108426    0.672174    0.622707    0.635976    0.585034
# 1115    0.575463    0.925805    0.024026    0.499594    0.635990    0.610282
# 1540    0.229425    0.068748    0.752691    0.658703    0.483481    0.696723
# 240     0.369138    0.056996    0.830701    0.707500    0.496776    0.627056
#
#       x_mean_Gyro  y_mean_Gyro  z_mean_Gyro  x_std_Acc  ...  \
# 1642     0.463111     0.526087     0.629051   0.243171  ...
# 2010     0.420936     0.571206     0.791617   0.273436  ...
# 1115     0.450452     0.515162     0.674022   0.013696  ...
# 1540     0.550742     0.228620     0.414985   0.255477  ...
# 240      0.473370     0.541198     0.610567   0.272285  ...
#
#       y_argmin_fft_Gyro  z_argmin_fft_Gyro  x_arg_diff_fft_Acc  \
# 1642           0.964286           0.428571            0.153846
# 2010           0.107143           0.714286            0.115385
# 1115           0.428571           0.321429            0.538462
# 1540           0.357143           0.785714            0.807692
# 240            0.035714           0.785714            0.115385
#
#       y_arg_diff_fft_Acc  z_arg_diff_fft_Acc  x_arg_diff_fft_Lin  \
# 1642            0.500000            0.192308            0.384615
# 2010            0.192308            0.461538            0.307692
# 1115            0.000000            0.846154            0.076923
# 1540            0.730769            0.038462            0.346154
# 240             0.576923            0.115385            0.769231
#
#       y_arg_diff_fft_Lin  z_arg_diff_fft_Lin  x_arg_diff_fft_Gyro  \
# 1642            0.500000            0.615385             0.500000
# 2010            0.076923            0.461538             0.115385
# 1115            0.423077            0.653846             0.076923
# 1540            0.423077            0.461538             0.500000
# 240             0.576923            0.115385             0.384615
#
#       y_arg_diff_fft_Gyro
# 1642             0.730769
# 2010             0.115385
# 1115             0.423077
# 1540             0.346154
# 240              0.307692
#
# [5 rows x 335 columns]

# %%
y_train.head()
# Out:
# 1642    5
# 2010    6
# 1115    3
# 1540    5
# 240     0
# Name: label_of_activity, dtype: int64

# %%
#X = d1.loc[:,0:335]
#y = d1[]
#from sklearn import preprocessing
#label_encoder = preprocessing.LabelEncoder()
#y=label_encoder.fit_transform(y)

# %%
# import necessary library
from sklearn.feature_selection import VarianceThreshold

# we're setting variance threshold at 0
var_thres=VarianceThreshold(threshold=0)

# fitting this variance threshold in all columns of Newly Created  training data
var_thres.fit(X_train)

# get the number of constant columns (whoose variance is 0)
constant_columns = [column for column in X_train.columns if column not in X_train.columns[var_thres.get_support()]]
print(len(constant_columns))

# dropping constant columns
X_train.drop(constant_columns, axis=1, inplace=True)
# Out:
# 0

# %%
# function to get all features highly correlated (both positive and negative) with another for a given threshold
def correlation(dataset, threshold):
    col_corr = set()  #set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:  # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  #getting the name of the column
                col_corr.add(colname)
    return col_corr                        

corr_features = correlation(X_train, 0.95)
len(corr_features)
# Out:
# 167

# %%
# dropping highly correlated features
X_train.drop(corr_features, axis=1, inplace=True)

# %%
X_train.shape
# Out:
# (1466, 168)

# %%
## Importing Libraries
from sklearn.feature_selection import mutual_info_classif
#from sklearn.preprocessing import MinMaxScaler

## Copy data in another dataframe to retrieve latter
d=X_train.copy()

## Calculate mutual information
mutual_info = mutual_info_classif(X_train, y_train, random_state=0)
mutual_info

## Storing original data into X_train_new
X1_train = X_train.copy()

mutual_info = pd.Series(mutual_info)
mutual_info.index = X1_train.columns
print(mutual_info.sort_values(ascending = False))



## Visual Representaion
#figure(figsize=(10,10), dpi=100)
#ranked_features.----sort_values().plot(kind='barh')
#plt.axvline(x=0.005,c='r')
#plt.show()
# Out:
# y_min_Acc        1.690429
# z_max_Acc        1.671124
# y_max_Acc        1.611881
# z_mean_Acc       1.603698
# x_max_Acc        1.522926
#                    ...
# y_argmax_Gyro    0.000000
# x_argmax_Gyro    0.000000
# x_argmax_Acc     0.000000
# x_argmax_Lin     0.000000
# z_argmax_Acc     0.000000
# Length: 168, dtype: float64

# %%
import matplotlib.pyplot as plt
# adjust the figure size
from matplotlib.pyplot import figure
figure(figsize=(10,10), dpi=100)
mutual_info.sort_values().plot(kind='barh')
plt.axvline(x=0.15,c='r')

# %%
l5=[]
for i in range(len(list(mutual_info))):
    if list(mutual_info)[i]<=0.15:
        l5.append(list(X_train.columns)[i])

# %%
len(l5)
# Out:
# 32

# %%
X_train.drop(l5,axis=1,inplace=True)

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

## Fit ExtraTreesClassifier with best set of parameters
model = ExtraTreesClassifier(n_estimators=50, min_samples_split=2, min_samples_leaf=3, criterion='gini',random_state=0)
model.fit(X_train,y_train)
print("model.feature_importances_:\n")
print(model.feature_importances_)
print("\n")
print("X_train.columns:\n")
print(X_train.columns)
ranked_features = pd.Series(model.feature_importances_, index = X_train.columns)
# Out:
# model.feature_importances_:
#
# [2.45537202e-02 3.77615602e-02 5.34027513e-02 3.23844571e-03
#  1.14314171e-02 5.23204050e-03 4.49584791e-03 9.27140918e-03
#  2.33088222e-03 3.41582936e-02 2.07029050e-02 1.11113544e-02
print("Visual Representation of Feature Importance from Model (Red line indicates value=0.005):")

## Visual Representaion
figure(figsize=(10,10), dpi=100)
ranked_features.sort_values().plot(kind='barh')
plt.axvline(x=0.005,c='r')
plt.show()
# Out:
# Visual Representation of Feature Importance from Model (Red line indicates value=0.005):

# %%
l6=[]
for i in range(len(list(ranked_features))):
    if list(mutual_info)[i]<=0.005:
        l6.append(list(X_train.columns)[i])

# %%
len(l6)
# Out:
# 12

# %%
X_train.drop(l6,axis=1,inplace=True)

# %%
len(X_train.columns)
# Out:
# 124

# %%
from collections import Counter
counter = Counter(y_train)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))  ## balanced data
# Out:
# Class=5, n=202 (9.642%)
# Class=6, n=201 (9.594%)
# Class=3, n=218 (10.406%)
# Class=0, n=218 (10.406%)
# Class=1, n=212 (10.119%)
# Class=2, n=207 (9.881%)
# Class=4, n=208 (9.928%)

# %% [markdown]
# # Testing Data Preparation

# %%
X_test.drop(constant_columns, axis=1, inplace=True)
X_test.drop(corr_features, axis=1, inplace=True)
X_test.drop(l5,axis=1,inplace=True)
X_test.drop(l6,axis=1,inplace=True)

# %%
X_test.shape
# Out:
# (629, 124)

# %%
# all features excluded from tarining and testing
features_excluded_1= []
features_excluded_1.extend(constant_columns)
features_excluded_1.extend(corr_features)
features_excluded_1.extend(l5)
features_excluded_1.extend(l6)

# %%
len(features_excluded_1)
# Out:
# 211

# %%
features_excluded_1
# Out:
# ['x_pos_count_Gyro',
#  'z_max_fft_Lin',
#  'y_aad_Gyro',
#  'z_mad_fft_Gyro',
#  'sma_Lin',
#  'x_maxmin_diff_fft_Acc',
#  'y_energy_fft_Gyro',
#  'x_IQR_Lin',
#  'y_IQR_fft_Acc',
#  'z_aad_Gyro',
#  'y_std_fft_Lin',
#  'x_IQR_Acc',
#  'z_kurtosis_fft_Acc',
#  'y_maxmin_diff_fft_Gyro',
#  'z_mad_Lin',
#  'z_energy_fft_Lin',
#  'y_IQR_Lin',
#  'y_kurtosis_fft_Lin',
#  'z_energy_fft_Gyro',
#  'z_mean_fft_Acc',
#  'z_mad_Acc',
#  'z_maxmin_diff_fft_Lin',
#  'x_energy_Lin',
#  'x_maxmin_diff_fft_Lin',
#  'z_min_Lin',
#  'x_maxmin_diff_Gyro',
#  'x_min_Acc',
#  'z_peak_count_Lin',
#  'z_aad_fft_Acc',
#  'x_min_Lin',
#  'x_std_fft_Gyro',
#  'y_median_Gyro',
#  'y_min_Lin',
#  'z_energy_Acc',
#  'z_IQR_Gyro',
#  'z_mean_fft_Gyro',
#  'x_max_fft_Lin',
#  'x_maxmin_diff_Acc',
#  'avg_result_Gyro',
#  'z_std_fft_Lin',
#  'z_std_Acc',
#  'z_maxmin_diff_fft_Gyro',
#  'x_pos_count_Lin',
#  'sma_fft_Acc',
#  'sma_Gyro',
#  'x_max_fft_Acc',
#  'y_median_fft_Acc',
#  'z_max_fft_Gyro',
#  'z_energy_Lin',
#  'y_kurtosis_fft_Gyro',
#  'x_std_fft_Acc',
#  'y_IQR_fft_Gyro',
#  'y_std_fft_Acc',
#  'sma_fft_Lin',
#  'y_mad_Lin',
#  'y_pos_count_Lin',
#  'x_IQR_fft_Lin',
#  'x_mad_fft_Acc',
#  'x_mean_fft_Acc',
#  'avg_result_Lin',
#  'y_max_fft_Acc',
#  'y_median_fft_Gyro',
#  'z_maxmin_diff_Gyro',
#  'avg_result_Accl_fft_Lin',
#  'z_maxmin_diff_Acc',
#  'z_std_fft_Gyro',
#  'x_energy_fft_Lin',
#  'z_aad_Lin',
#  'z_IQR_Lin',
#  'y_max_fft_Lin',
#  'x_energy_fft_Acc',
#  'x_std_Lin',
#  'z_max_fft_Acc',
#  'x_energy_Gyro',
#  'y_max_fft_Gyro',
#  'x_aad_fft_Lin',
#  'x_std_fft_Lin',
#  'x_pos_count_Acc',
#  'y_mean_fft_Acc',
#  'z_mad_Gyro',
#  'y_IQR_Acc',
#  'z_std_Lin',
#  'y_std_fft_Gyro',
#  'y_aad_fft_Acc',
#  'y_energy_Acc',
#  'y_max_Lin',
#  'y_aad_Acc',
#  'y_aad_fft_Lin',
#  'y_pos_count_Gyro',
#  'z_pos_count_Gyro',
#  'x_mad_fft_Gyro',
#  'y_mad_Acc',
#  'x_energy_fft_Gyro',
#  'x_min_Gyro',
#  'y_peak_count_Lin',
#  'z_maxmin_diff_Lin',
#  'x_mad_Gyro',
#  'x_kurtosis_fft_Lin',
#  'z_kurtosis_fft_Gyro',
#  'y_aad_Lin',
#  'x_mean_fft_Lin',
#  'x_aad_Lin',
#  'y_maxmin_diff_fft_Acc',
#  'y_maxmin_diff_fft_Lin',
#  'z_energy_fft_Acc',
#  'y_energy_fft_Acc',
#  'sma_fft_Gyro',
#  'x_IQR_Gyro',
#  'x_max_Gyro',
#  'z_std_fft_Acc',
#  'x_kurtosis_fft_Gyro',
#  'x_std_Gyro',
#  'z_max_Lin',
#  'y_maxmin_diff_Acc',
#  'x_aad_fft_Gyro',
#  'avg_result_Accl_fft_Gyro',
#  'z_mad_fft_Lin',
#  'x_mad_fft_Lin',
#  'x_maxmin_diff_Lin',
#  'x_mad_Acc',
#  'z_median_fft_Lin',
#  'z_aad_Acc',
#  'y_std_Lin',
#  'x_median_Acc',
#  'z_mean_fft_Lin',
#  'y_median_fft_Lin',
#  'x_peak_count_Lin',
#  'x_aad_Acc',
#  'x_mad_Lin',
#  'y_mad_fft_Lin',
#  'x_kurtosis_fft_Acc',
#  'x_aad_Gyro',
#  'x_maxmin_diff_fft_Gyro',
#  'z_energy_Gyro',
#  'y_pos_count_Acc',
#  'z_pos_count_Acc',
#  'y_energy_Lin',
#  'x_max_Lin',
#  'y_kurtosis_fft_Acc',
#  'y_IQR_fft_Lin',
#  'x_max_fft_Gyro',
#  'x_mean_fft_Gyro',
#  'y_mean_fft_Lin',
#  'z_IQR_fft_Lin',
#  'y_median_Acc',
#  'x_median_fft_Gyro',
#  'z_IQR_fft_Acc',
#  'y_IQR_Gyro',
#  'y_maxmin_diff_Gyro',
#  'x_aad_fft_Acc',
#  'y_maxmin_diff_Lin',
#  'z_median_fft_Acc',
#  'y_aad_fft_Gyro',
#  'z_median_Acc',
#  'z_pos_count_Lin',
#  'z_mad_fft_Acc',
#  'x_IQR_fft_Acc',
#  'avg_result_Accl_fft_Acc',
#  'y_mad_Gyro',
#  'z_aad_fft_Lin',
#  'z_aad_fft_Gyro',
#  'y_std_Acc',
#  'y_mean_fft_Gyro',
#  'x_median_fft_Lin',
#  'y_energy_fft_Lin',
#  'z_IQR_Acc',
#  'z_maxmin_diff_fft_Acc',
#  'z_above_mean_Lin',
#  'x_peak_count_fft_Acc',
#  'y_peak_count_fft_Acc',
#  'z_peak_count_fft_Acc',
#  'x_peak_count_fft_Lin',
#  'y_peak_count_fft_Lin',
#  'z_peak_count_fft_Lin',
#  'x_peak_count_fft_Gyro',
#  'y_peak_count_fft_Gyro',
#  'z_peak_count_fft_Gyro',
#  'x_argmax_Acc',
#  'y_argmax_Acc',
#  'z_argmax_Acc',
#  'x_argmax_Lin',
#  'y_argmax_Lin',
#  'z_argmax_Lin',
#  'x_argmax_Gyro',
#  'y_argmax_Gyro',
#  'z_argmax_Gyro',
#  'x_argmin_Acc',
#  'y_argmin_Acc',
#  'z_argmin_Acc',
#  'x_argmin_Lin',
#  'y_argmin_Lin',
#  'z_argmin_Lin',
#  'x_argmin_Gyro',
#  'y_argmin_Gyro',
#  'z_argmin_Gyro',
#  'x_argmax_fft_Gyro',
#  'z_argmin_fft_Lin',
#  'z_arg_diff_fft_Acc',
#  'z_arg_diff_fft_Lin',
#  'y_argmax_fft_Acc',
#  'z_argmax_fft_Acc',
#  'x_argmax_fft_Lin',
#  'y_argmax_fft_Lin',
#  'z_argmax_fft_Gyro',
#  'x_argmin_fft_Acc',
#  'y_argmin_fft_Acc',
#  'z_argmin_fft_Acc',
#  'y_argmin_fft_Lin',
#  'x_argmin_fft_Gyro',
#  'z_argmin_fft_Gyro',
#  'x_arg_diff_fft_Acc']

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
# We'll also check cross validation score from training set
# Import library for Repeated Random Cross Validation
from sklearn.model_selection import ShuffleSplit
ssplit = ShuffleSplit(n_splits=10,test_size=0.30,random_state=0)

# import library for RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
# creating hyperparameter grid
c_space=np.logaspace=(-5,8,15)
params_LOG = {'C':c_space,
              'max_iter':[50,100,150,200,500,1000],
              'multi_class' : ['ovr', 'multinomial']}

# instantiating logistic regression Classifier
Randomized_search_LOG = LogisticRegression(solver='lbfgs',random_state=0)

# instantiating RandomizedSearchCV
Randomized_search_LOG = RandomizedSearchCV(Randomized_search_LOG,params_LOG,verbose=1, cv=5)
Randomized_search_LOG.fit(X_train,y_train)
best_params_LOG = Randomized_search_LOG.fit(X_train,y_train)

# print tuned parameters and score
print('Tuned Logistic Regression Parameters are:{}'.format(Randomized_search_LOG.best_params_))
print('Score:{}'.format(Randomized_search_LOG.best_score_))

predictions_training_LOG = Randomized_search_LOG.predict(X_train)
predictions_testing_LOG = Randomized_search_LOG.predict(X_test)


#print("Training accuracy of Logistic Regression: ", format(accuracy_score(y_train,predictions_training_SVM),"0.2f"))
print("Training accuracy of Logistic Regression after Cross Validation in training portion:{}".format(accuracy_score(y_train,predictions_training_LOG),"0.2f"))
print("Testing accuracy of Logistic Regression:{}".format(accuracy_score(y_test,predictions_testing_LOG),"0.2f"))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.99590908        nan 0.99659167 0.99659167        nan        nan
#  0.99659167 0.99659167 0.99659167 0.99659167]
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1309, in fit
#     raise ValueError("Penalty term must be positive; got (C=%r)"
# ValueError: Penalty term must be positive; got (C=-5)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.99659167 0.99590908        nan 0.99659167
#  0.99659167        nan 0.99659167        nan]
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Tuned Logistic Regression Parameters are:{'multi_class': 'multinomial', 'max_iter': 100, 'C': 8}
# Score:0.9965916742123471
# Training accuracy of Logistic Regression after Cross Validation in training portion:1.0
# Testing accuracy of Logistic Regression:0.9984101748807631

# %%
## Confusion Matrix
cm_LOG = confusion_matrix(y_test, predictions_testing_LOG)
print("Confusion Matrix : \n", cm_LOG)

## Classification Report
print(classification_report(y_test, predictions_testing_LOG))

## probability of falling into a particular class from each observation
probs_LOG = best_params_LOG.predict_proba(X_test)
probs_LOG = probs_LOG[:,1]
probs_LOG
# Out:
# Confusion Matrix :
#  [[80  0  0  0  0  0  0]
#  [ 0 88  0  0  0  0  0]
#  [ 0  0 93  0  0  0  0]
#  [ 0  0  1 81  0  0  0]
#  [ 0  0  0  0 92  0  0]
#  [ 0  0  0  0  0 98  0]
#  [ 0  0  0  0  0  0 96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        88
#            2       0.99      1.00      0.99        93
#            3       1.00      0.99      0.99        82
#            4       1.00      1.00      1.00        92
#            5       1.00      1.00      1.00        98
#            6       1.00      1.00      1.00        96
#
#     accuracy                           1.00       629
#    macro avg       1.00      1.00      1.00       629
# weighted avg       1.00      1.00      1.00       629
# array([2.06612453e-06, 6.25516572e-05, 7.15426145e-06, 9.92124837e-01,
#        5.39855882e-04, 6.28299334e-06, 9.99138205e-01, 1.97771105e-05,
#        2.58941058e-04, 3.15672641e-04, 2.72443968e-04, 9.55055224e-01,
#        2.02333826e-04, 2.59050118e-05, 4.78158493e-06, 9.99358304e-01,
#        6.31450585e-06, 1.51908172e-05, 6.21661140e-04, 7.07018093e-04,
#        9.99425992e-01, 4.70391180e-04, 7.81696026e-05, 5.00395311e-05,
#        2.40415680e-04, 9.73887157e-04, 7.38579579e-05, 2.36041045e-05,
#        3.48970817e-04, 6.12991432e-04, 1.87152582e-04, 5.57998424e-05,
#        7.12257101e-04, 1.42315919e-04, 7.12369252e-03, 9.98527983e-01,
#        9.99386606e-01, 9.99480265e-01, 9.99606727e-01, 1.14070156e-05,
#        7.34535840e-04, 8.11123175e-06, 7.21907959e-05, 9.99558669e-01,
#        9.99551211e-01, 3.27403427e-04, 2.18383323e-04, 2.81463441e-05,
#        9.98881321e-01, 9.98577739e-01, 1.12419181e-04, 9.59019884e-06,
#        1.68947818e-03, 2.44390450e-04, 3.54861188e-04, 2.26649231e-04,
#cl=LogisticRegression(C=15,
#              max_iter=500,
              #multi_class= 'ovr',solver='lbfgs',random_state=0)
#cl.fit(X_train,y_train)
#print('accuracy_scorec:{}'.format(accuracy_score(y_train,cl.predict(X_train))))
#print('accuracy_scorec:{}'.format(accuracy_score(y_test,cl.predict(X_test))))

# %%
#from sklearn.model_selection import cross_val_score
#from sklearn.model_selection import RepeatedStratifiedKFold
#cv=RepeatedStratifiedKFold(n_splits=5,n_repeats=2,random_state=0)
#n_scores=cross_val_score(classifier,X,y,scoring='accuracy',cv=cv,n_jobs=-1)
#n_scores.mean()

# %% [markdown]
# # SVM

# %%
# import library for RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# Import library to calculate cross validation score
from sklearn.model_selection import cross_val_score

# %%
# import library for Support Vector Machine
from sklearn.svm import SVC

# We'll also check cross validation score from training set
# Import library for Repeated Random Cross Validation
#from sklearn.model_selection import ShuffleSplit
#ssplit = ShuffleSplit(n_splits=10,test_size=0.30)

# import library for DecisionTree
from sklearn.svm import SVC

# make parameter Randomized for Support Vector Machine
params_SVM = {
    'C':[0.1, 1, 10, 100, 1000],
    'gamma':[1, 0.1, 0.01, 0.001, 0.0001],
    'kernel':['linear','poly','rbf']
}
print('Parameters to check are:\n',params_SVM)

# fitting Randomized_search on RandomizedForestClassifier and getting the best hyperparameters
Randomized_search_SVM = RandomizedSearchCV(SVC(probability=True, random_state=0), params_SVM, verbose=1, cv=5)
Randomized_search_SVM.fit(X_train, y_train)
best_params_SVM = Randomized_search_SVM.fit(X_train, y_train)

# print tuned parameters and score
print('Tuned SVC Parameters are:{}'.format(Randomized_search_SVM.best_params_))
print('Score:{}'.format(Randomized_search_SVM.best_score_))  # Mean cross-validated score of the best_estimator
predictions_training_SVM = Randomized_search_SVM.predict(X_train)
predictions_testing_SVM = Randomized_search_SVM.predict(X_test)

#print("Training accuracy of Support Vector Machine: ", format(accuracy_score(y_train,predictions_training_SVM),"0.2f"))
print("Training accuracy of Support Vector Machine after Cross Validation in training portion:{}".format(accuracy_score(y_train,predictions_training_SVM),"0.2f"))
print("Testing accuracy of Support Vector Machine:{}".format(accuracy_score(y_test,predictions_testing_SVM),"0.2f"))
# Out:
# Parameters to check are:
#  {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 'kernel': ['linear', 'poly', 'rbf']}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Tuned SVC Parameters are:{'kernel': 'linear', 'gamma': 0.1, 'C': 1000}
# Score:0.9965916742123471
# Training accuracy of Support Vector Machine after Cross Validation in training portion:1.0
# Testing accuracy of Support Vector Machine:0.9968203497615262

# %%
## Confusion Matrix
cm_SVM = confusion_matrix(y_test, predictions_testing_SVM)
print("Confusion Matrix : \n", cm_SVM)

## Classification Report
print(classification_report(y_test, predictions_testing_SVM))

## probability of falling into a particular class from each observation
probs_SVM = best_params_SVM.predict_proba(X_test)
probs_SVM = probs_SVM[:,1]
probs_SVM
# Out:
# Confusion Matrix :
#  [[80  0  0  0  0  0  0]
#  [ 0 88  0  0  0  0  0]
#  [ 0  0 93  0  0  0  0]
#  [ 0  0  1 81  0  0  0]
#  [ 0  0  0  0 92  0  0]
#  [ 0  0  0  0  0 97  1]
#  [ 0  0  0  0  0  0 96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00
#        3.05856706e-03, 9.92470247e-04, 8.97229876e-03, 1.83898602e-03,
#        5.75596271e-03, 1.11963218e-03, 9.91673150e-01, 1.02378333e-03,
#        4.89052772e-04, 4.45097257e-04, 1.99740647e-03, 1.40824249e-03,
#        2.85397785e-03, 3.21589694e-03, 9.85580504e-04, 5.22878316e-03,
#        4.05001944e-04, 2.91323550e-03, 9.87144067e-01, 1.13435938e-03,
#        3.97229346e-03, 3.55407571e-03, 9.70512007e-01, 4.22921483e-03,
#        3.49068688e-03, 7.08081015e-04, 1.27112800e-03, 1.00455443e-04,
#        9.33703799e-04, 1.54920848e-03, 9.95284669e-01, 4.92001844e-03,
#        2.16629931e-03, 4.05743252e-04, 3.21791032e-03, 2.36765629e-03,
#        3.42418599e-04, 3.74790654e-03, 7.35457715e-04, 5.29538901e-04,
#        9.86688475e-01, 1.98130379e-03, 3.24382624e-04, 2.55972595e-02,
#        6.60063332e-03, 2.91832892e-03, 1.52679761e-03, 2.01262780e-03,
#        3.51773202e-03, 2.42599369e-03, 1.26763619e-03, 7.56894457e-04,
#        5.57806302e-03, 9.93180162e-01, 9.92668127e-01, 4.93533571e-04,
#        2.02287029e-03, 1.40223373e-03, 3.57457385e-03, 1.79923502e-03,
#        1.82285805e-03, 2.38643468e-03, 1.16539921e-02, 1.90645694e-03,
#        3.90579117e-03, 6.40154956e-04, 1.14592192e-03, 2.98375657e-03,
#        9.90611319e-03, 1.64767197e-03, 1.01589618e-03, 5.02557077e-04,
#        1.82968870e-03])

# %%
#Randomized_search_SVM.cv_results_

# %%
#score=cross_val_score(SVC(C=1000, gamma=0.1, probability=True, random_state=0),X_train_new, y_train, cv=ssplit)
#score=cross_val_score(SVC(C=1000, gamma=0.001, probability=True, random_state=0),X_train, y_train, cv=ssplit)
#predictions_training_SVM_CV=score.mean()     
#predictions_testing_SVM = Randomized_search_SVM.predict(X_test)


#print("Training accuracy of Support Vector Machine: ", format(accuracy_score(y_train,predictions_training_SVM),"0.2f"))
#print("Training accuracy of Support Vector Machine after Cross Validation in training portion: ", format(predictions_training_SVM_CV,"0.2f"))
#print("Testing accuracy of Support Vector Machine: ", format(accuracy_score(y_test,predictions_testing_SVM),"0.2f"))

# %% [markdown]
# # Random Forest

# %%
# import library for RandomForest
from sklearn.ensemble import RandomForestClassifier

# %%
# make parameter Randomized for DecisionTree
params_RFC = {
    'criterion': ['entropy','gini'],
    
    'max_depth': [int(x) for x in np.linspace(10,100,5)],
    
    'max_features': ['auto','sqrt','log2'],
    
    'min_samples_leaf': [2,5,8],
    
    'min_samples_split': [2,5,10],
    
    'n_estimators': [int(x) for x in np.linspace(start=100, stop=500, num=5)]
}
print('Parameters to check are:\n',params_RFC)

# fitting Randomized_search on RandomForestClassifier and getting the best hyperparameters
Randomized_search_RFC = RandomizedSearchCV(RandomForestClassifier(random_state=0), params_RFC, verbose=1, cv=5)
Randomized_search_RFC.fit(X_train, y_train)
best_params_RFC = Randomized_search_RFC.fit(X_train, y_train)

# print tuned parameters and score
print('Tuned SVC Parameters are:{}'.format(Randomized_search_RFC.best_params_))
print('Score:{}'.format(Randomized_search_RFC.best_score_))  # Mean cross-validated score of the best_estimator
predictions_training_RFC = Randomized_search_RFC.predict(X_train)
predictions_testing_RFC = Randomized_search_RFC.predict(X_test)


#print("Training accuracy of Support Vector Machine: ", format(accuracy_score(y_train,predictions_training_RFC),"0.2f"))
print("Training accuracy of Random Forest Classifier after Cross Validation in training portion:{}".format(accuracy_score(y_train,predictions_training_RFC),"0.2f"))
print("Testing accuracy of Random Forest Classifier:{}".format(accuracy_score(y_test,predictions_testing_RFC),"0.2f"))
# Out:
# Parameters to check are:
#  {'criterion': ['entropy', 'gini'], 'max_depth': [10, 32, 55, 77, 100], 'max_features': ['auto', 'sqrt', 'log2'], 'min_samples_leaf': [2, 5, 8], 'min_samples_split': [2, 5, 10], 'n_estimators': [100, 200, 300, 400, 500]}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Tuned SVC Parameters are:{'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'entropy'}
# Score:0.9952288082468483
# Training accuracy of Random Forest Classifier after Cross Validation in training portion:0.9979536152796725
# Testing accuracy of Random Forest Classifier:0.9952305246422893

# %%
## Confusion Matrix
cm_RFC = confusion_matrix(y_test, predictions_testing_RFC)
print("Confusion Matrix : \n", cm_RFC)

## Classification Report
print(classification_report(y_test, predictions_testing_RFC))

## probability of falling into a particular class from each observation
probs_RFC = best_params_RFC.predict_proba(X_test)
probs_RFC = probs_RFC[:,1]
probs_RFC
# Out:
# Confusion Matrix :
#  [[80  0  0  0  0  0  0]
#  [ 0 88  0  0  0  0  0]
#  [ 0  0 93  0  0  0  0]
#  [ 0  0  1 81  0  0  0]
#  [ 0  0  0  0 92  0  0]
#  [ 0  0  0  0  0 97  1]
#  [ 0  0  0  0  0  1 95]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        88
#            2       0.99      1.00      0.99        93
#            3       1.00      0.99      0.99        82
#            4       1.00      1.00      1.00        92
#            5       0.99      0.99      0.99        98
#            6       0.99      0.99      0.99        96
#
#     accuracy                           1.00       629
#    macro avg       1.00      1.00      1.00       629
# weighted avg       1.00      1.00      1.00       629
# array([0.00000000e+00, 1.63672439e-03, 0.00000000e+00, 8.35199500e-01,
#        8.40238095e-03, 2.04761905e-03, 9.24415308e-01, 6.00000000e-04,
#        1.04404762e-03, 1.11666667e-03, 2.03237734e-02, 8.38511766e-01,
#        3.36666667e-03, 1.20104895e-03, 4.00000000e-04, 9.98764203e-01,
#        2.29848485e-03, 2.22222222e-04, 6.33333333e-03, 1.33825372e-01,
#        9.87372944e-01, 2.91666667e-03, 1.65500555e-02, 4.26617827e-03,
#        1.61428571e-03, 2.13267066e-02, 4.63701299e-03, 1.23306166e-02,
#        3.92207792e-03, 2.26666667e-03, 2.00000000e-03, 2.30808081e-03,
#        1.43571429e-03, 5.71428571e-04, 1.37667610e-02, 9.02649109e-01,
#        9.97851038e-01, 9.95896104e-01, 9.95958974e-01, 1.12307692e-03,
#        3.33333333e-04, 1.00086580e-03, 2.11428571e-03, 9.99285714e-01,
#        1.33055556e-03, 5.18918581e-03, 7.60073260e-04, 2.20173993e-03,
#        3.22517483e-03, 4.80494505e-03, 2.58333333e-03, 0.00000000e+00,
#        5.00000000e-04])

# %%
#score=cross_val_score(RandomForestClassifier(......),X_train, y_train, cv=ssplit)
#predictions_training_RFC_CV=score.mean()
#predictions_testing_RFC = Randomized_search_RFC.predict(X_test)

#print("Training accuracy of Random Forest Classifier: ", format(accuracy_score(y_train,predictions_training_RFC),"0.2f"))
#print("Training accuracy of Random Forest Classifier after Cross Validation: ", format(predictions_training_RFC_CV,"0.2f"))
#print("Testing accuracy of Random Forest Classifier: ", format(accuracy_score(y_test,predictions_testing_RFC),"0.2f"))

# %%
## AUC (Area Under Curve) Score
#auc_score_RFC = roc_auc_score(y_test, probs_RFC)
#print("Random Forest Classifier ROC AUC = ",format(auc_score_RFC,"0.2f"))

## no skill prediction (majority class)
#ns_probs = [0 for _ in range(len(y_test))]
#ns_auc = roc_auc_score(y_test, ns_probs)
#ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
#plt.plot(ns_fpr, ns_tpr, marker='.', label='No Skill Model')


## ROC Curve from Random Forest
#fpr_RFC, tpr_RFC, __RFC = roc_curve(y_test, probs_RFC)
#plt.plot(fpr_RFC, tpr_RFC, linestyle='--', label='Random Forest')
#plt.title("ROC Curve for Random Forest Classifier")

# axis labels
#plt.xlabel('False Positive Rate')
#plt.ylabel('True Positive Rate')
# show legend
#plt.legend()
# show the plot
#plt.show()

# %%
## AUC (Area Under Curve) Score
#auc_score_LOG = roc_auc_score(y_test, probs_LOG)
#print("Support Vector Machine ROC AUC = ",format(auc_score_LOG,"0.2f"))

## no skill prediction (majority class)
#ns_probs = [0 for _ in range(len(y_test))]
#ns_auc = roc_auc_score(y_test, ns_probs)
#ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
#plt.plot(ns_fpr, ns_tpr, marker='.', label='No Skill Model')

## ROC Curve of Support Vector Machine
#fpr_LOG, tpr_LOG, __LOG = roc_curve(y_test, probs_LOG)
#plt.plot(fpr_LOG, tpr_LOG, linestyle='--', label='Support Vector Machine')
#plt.title("ROC Curve for Support Vector Machine")

# axis labels
#plt.xlabel('False Positive Rate')
#plt.ylabel('True Positive Rate')
# show legend
#plt.legend()
# show the plot
#plt.show()

# %%
## AUC (Area Under Curve) Score
#auc_score_SVM = roc_auc_score(y_test, probs_SVM)
#print("Support Vector Machine ROC AUC = ",format(auc_score_SVM,"0.2f"))

## no skill prediction (majority class)
#ns_probs = [0 for _ in range(len(y_test))]
#ns_auc = roc_auc_score(y_test, ns_probs)
#ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
#plt.plot(ns_fpr, ns_tpr, marker='.', label='No Skill Model')

## ROC Curve of Support Vector Machine
#fpr_SVM, tpr_SVM, __SVM = roc_curve(y_test, probs_SVM)
#plt.plot(fpr_SVM, tpr_SVM, linestyle='--', label='Support Vector Machine')
#plt.title("ROC Curve for Support Vector Machine")

# axis labels
#plt.xlabel('False Positive Rate')
#plt.ylabel('True Positive Rate')
# show legend
#plt.legend()
# show the plot
#plt.show()
